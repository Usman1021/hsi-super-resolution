# %% [markdown]
# ## Download the dataset from the following link before using this notebook (Chikusei Centre scene):

# %% [markdown]
# ##  https://www.kaggle.com/datasets/mingliu123/chikusei

# %% [markdown]
# ## Import required libraries

# %%
import numpy as np
import h5py
import random
from scipy.io import loadmat
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, UpSampling2D, Add, Activation, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.losses import MeanSquaredError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping
from skimage.metrics import structural_similarity as ssim
# GPU setup
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("✅ GPU available. Using:", gpus[0])
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
else:
    print("❌ GPU not available. Running on CPU.")
# Out:
# 2025-08-01 11:23:24.764756: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-01 11:23:24.795391: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754036604.811862 2067514 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754036604.817153 2067514 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-01 11:23:24.835628: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✅ GPU available. Using: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# ##  Reproducibility Setup ( Set a consistent random seed for NumPy, TensorFlow, and Python's random module to ensure the same results on each run)

# %%
seed_value = 42
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)
os.environ['PYTHONHASHSEED'] = str(seed_value)

tf.config.experimental.enable_op_determinism()
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

# %% [markdown]
# ##  Load the Chikusei Dataset

# %%
# -----------------------------
# Load Chikusei dataset
# -----------------------------
with h5py.File("Chikusei.mat", "r") as f:
    raw_data = f['chikusei'][:]

# Transpose to (H, W, B)
if raw_data.shape[0] <= 300:
    hyperspectral_image = raw_data.transpose(1, 2, 0)
else:
    hyperspectral_image = raw_data

print("Original image shape:", hyperspectral_image.shape)
# Out:
# Original image shape: (2335, 2517, 128)

# %% [markdown]
# ##  Parameter Initialization for dataset preprocessing only

# %%
# -----------------------------
# Parameters
# -----------------------------
crop_height = 512
crop_width = 512
crop_bands = 128

test_patch_size = (128, 128)
train_patch_size = (128, 128)
downscale_factor = 2
nodata_value = 15000
overlap = 32
validation_ratio = 0.1

# %% [markdown]
# ## Crop center region for training and testing

# %%
# -----------------------------
# Crop center region
# -----------------------------
H, W, B = hyperspectral_image.shape
start_i = (H - crop_height) // 2
start_j = (W - crop_width) // 2

cropped_image = hyperspectral_image[start_i:start_i + crop_height,
                                    start_j:start_j + crop_width,
                                    :crop_bands]

print("Cropped subimage shape:", cropped_image.shape)
# Out:
# Cropped subimage shape: (512, 512, 128)

# %% [markdown]
# ## Extract test set

# %%
# -----------------------------
# Extract test set: 2 non-overlapping patches from top rows
# -----------------------------
test_hr_list, test_lr_list = [], []
patch_h, patch_w = test_patch_size

for j in range(0, 2 * patch_w, patch_w):
    if j + patch_w > crop_width:
        continue

    patch = cropped_image[0:patch_h, j:j + patch_w, :]
    if patch.shape[:2] != test_patch_size or np.any(patch >= nodata_value):
        continue

    patch_tf = tf.convert_to_tensor(patch[np.newaxis, ...], dtype=tf.float32)
    patch_lr_tf = tf.image.resize(
        patch_tf,
        [patch_h // downscale_factor, patch_w // downscale_factor],
        method='area'
    )
    patch_lr = patch_lr_tf[0].numpy()

    test_hr_list.append(patch)
    test_lr_list.append(patch_lr)

X_test_hr = np.stack(test_hr_list)
X_test_lr = np.stack(test_lr_list)
# Out:
# I0000 00:00:1754036647.169958 2067514 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31141 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:61:00.0, compute capability: 7.0

# %% [markdown]
# ## Extract Training Patches

# %%
# -----------------------------
# Extract training/validation from remaining region
# -----------------------------
train_hr, train_lr = [], []
stride = train_patch_size[0] - overlap
train_h, train_w = train_patch_size

for i in range(patch_h, crop_height - train_h + 1, stride):
    for j in range(0, crop_width - train_w + 1, stride):
        patch = cropped_image[i:i + train_h, j:j + train_w, :]

        if patch.shape[:2] != train_patch_size or np.any(patch >= nodata_value):
            continue

        patch_tf = tf.convert_to_tensor(patch[np.newaxis, ...], dtype=tf.float32)
        patch_lr_tf = tf.image.resize(
            patch_tf,
            [train_h // downscale_factor, train_w // downscale_factor],
            method='area'
        )
        patch_lr = patch_lr_tf[0].numpy()

        train_hr.append(patch)
        train_lr.append(patch_lr)

train_hr = np.array(train_hr)
train_lr = np.array(train_lr)

# %% [markdown]
# ## Validation Split FOR train and validation

# %%
# -----------------------------
# Split 10% into validation set
# -----------------------------
indices = np.arange(train_hr.shape[0])
np.random.shuffle(indices)

val_count = max(1, int(validation_ratio * len(indices)))
X_validation_hr = train_hr[indices[:val_count]]
X_validation_lr = train_lr[indices[:val_count]]
X_train_hr = train_hr[indices[val_count:]]
X_train_lr = train_lr[indices[val_count:]]

# -----------------------------
# Print dataset shapes
# -----------------------------
print("\n✅ Dataset summary:")
print("X_test_hr:", X_test_hr.shape)
print("X_test_lr:", X_test_lr.shape)
print("X_train_hr:", X_train_hr.shape)
print("X_train_lr:", X_train_lr.shape)
print("X_validation_hr:", X_validation_hr.shape)
print("X_validation_lr:", X_validation_lr.shape)
print(f"Validation samples: {val_count} / {len(indices)}")
# Out:
# ✅ Dataset summary:
# X_test_hr: (2, 128, 128, 128)
# X_test_lr: (2, 64, 64, 128)
# X_train_hr: (14, 128, 128, 128)
# X_train_lr: (14, 64, 64, 128)
# X_validation_hr: (1, 128, 128, 128)
# X_validation_lr: (1, 64, 64, 128)
# Validation samples: 1 / 15

# %% [markdown]
# ##  Model development

# %%
# -----------------------------
# Custom Loss Function: Spatial + Spectral Gradient + MSE
# -----------------------------
def spatial_spectral_gradient_loss(weight_mse=1.0, weight_spatial=0.1, weight_spectral=0.1):
    def loss_fn(y_true, y_pred):
        mse_loss = K.mean(K.square(y_true - y_pred))

        grad_true_x = y_true[:, 1:, :, :] - y_true[:, :-1, :, :]
        grad_pred_x = y_pred[:, 1:, :, :] - y_pred[:, :-1, :, :]
        grad_true_y = y_true[:, :, 1:, :] - y_true[:, :, :-1, :]
        grad_pred_y = y_pred[:, :, 1:, :] - y_pred[:, :, :-1, :]
        spatial_loss = K.mean(K.square(grad_true_x - grad_pred_x)) + K.mean(K.square(grad_true_y - grad_pred_y))

        grad_true_s = y_true[:, :, :, 1:] - y_true[:, :, :, :-1]
        grad_pred_s = y_pred[:, :, :, 1:] - y_pred[:, :, :, :-1]
        spectral_loss = K.mean(K.square(grad_true_s - grad_pred_s))

        return weight_mse * mse_loss + weight_spatial * spatial_loss + weight_spectral * spectral_loss

    return loss_fn

# -----------------------------
# Residual Block
# -----------------------------
def resnet_block(x, filters):
    shortcut = x
    x = Conv2D(filters, 3, padding='same', activation='relu')(x)
    x = Conv2D(filters, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# -----------------------------
# Spectral Unmixing Block
# -----------------------------
def spectral_unmixing_block(x, filters):
    x = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)
    x = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)
    return x

# -----------------------------
# Spectral–Spatial Fusion Block
# -----------------------------
def spectral_spatial_fusion_block(x, filters):
    spatial = Conv2D(filters, kernel_size=3, padding='same', activation='relu')(x)
    spectral = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)
    fused = Concatenate()([spatial, spectral])
    fused = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(fused)
    return fused

# -----------------------------
# Model Architecture (Fully Convolutional)
# -----------------------------
def build_simple_sr_model(input_shape=(None, None, 128)):
    inputs = Input(shape=input_shape)

    # Pre-Upsampling
    x = UpSampling2D(size=(2, 2), interpolation='bilinear')(inputs)

    x = spectral_unmixing_block(x, filters=64)
    x = spectral_spatial_fusion_block(x, filters=64)
    x = Conv2D(64, 3, padding='same', activation='relu')(x)

    for _ in range(3):
        x = resnet_block(x, 64)

    output = Conv2D(input_shape[-1], 3, padding='same', activation='linear')(x)

    return Model(inputs, output, name='SR_Model_PreUpsampling')

# -----------------------------
# Build and Compile Model
# -----------------------------
model = build_simple_sr_model(input_shape=(None, None, 128))

model.compile(
    optimizer='adam',
    loss=spatial_spectral_gradient_loss(
        weight_mse=2.0,
        weight_spatial=0.1,
        weight_spectral=0.1
    ),
    metrics=[MeanSquaredError()]
)

# -----------------------------
# Parameter Count
# -----------------------------
total_params = model.count_params()
size_in_bytes = total_params * 4
size_in_mb = size_in_bytes / (1024 ** 2)

print(f"📢 Model size: {size_in_mb:.2f} MB")
print(f"📊 Total Parameters: {total_params / 1e6:.2f} Million")
# Out:
# 📢 Model size: 1.51 MB
# 📊 Total Parameters: 0.39 Million

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Train the model and get the training history with early stopping
history = model.fit(
    X_train_lr, 
    X_train_hr, 
    epochs=1500, 
    batch_size=4, 
    validation_data=(X_validation_lr, X_validation_hr),
    callbacks=[early_stopping]  # Add the early stopping callback here
)

# Visualize training and validation loss over epochs
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)  # Add grid for better readability
plt.show()
# Out:
# Epoch 1/1500
# 2025-08-01 11:24:09.630188: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754036653.057707 2067653 service.cc:148] XLA service 0x7efc48421620 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754036653.057733 2067653 service.cc:156]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2025-08-01 11:24:13.147868: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1754036653.579168 2067653 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4911311.5000 - mean_squared_error: 2446371.5000
# 2025-08-01 11:24:16.021531: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion', 128 bytes spill stores, 120 bytes spill loads
#
# I0000 00:00:1754036656.042826 2067653 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - loss: 4730490.5000 - mean_squared_error: 2329726.0000
# 2025-08-01 11:24:18.763627: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4621997.5000 - mean_squared_error: 2259738.7500 - val_loss: 1929055.0000 - val_mean_squared_error: 910218.3750
# Epoch 2/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1586696.8750 - mean_squared_error: 731544.8125 - val_loss: 455002.6250 - val_mean_squared_error: 217897.5469
# Epoch 3/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 530691.1875 - mean_squared_error: 251614.2656 - val_loss: 422506.7500 - val_mean_squared_error: 200921.2500
# Epoch 4/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 453869.9062 - mean_squared_error: 213176.9844 - val_loss: 282098.2500 - val_mean_squared_error: 133644.1250
# Epoch 5/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 323968.0625 - mean_squared_error: 151427.9688 - val_loss: 191086.0469 - val_mean_squared_error: 90636.8125
# Epoch 6/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 224130.6250 - mean_squared_error: 104811.9062 - val_loss: 139893.3594 - val_mean_squared_error: 65717.1641
# Epoch 7/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 179991.0469 - mean_squared_error: 83426.2969 - val_loss: 126595.9609 - val_mean_squared_error: 59516.1406
# Epoch 8/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 153834.6094 - mean_squared_error: 71246.8906 - val_loss: 96451.4062 - val_mean_squared_error: 45439.7266
# Epoch 9/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 130673.0859 - mean_squared_error: 60478.9258 - val_loss: 82492.8281 - val_mean_squared_error: 38710.3633
# Epoch 10/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 117267.2891 - mean_squared_error: 54096.0742 - val_loss: 73850.6875 - val_mean_squared_error: 34521.3398
# Epoch 11/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 109757.2422 - mean_squared_error: 50613.7148 - val_loss: 66908.7578 - val_mean_squared_error: 31169.6816
# Epoch 12/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 101462.6250 - mean_squared_error: 46603.4414 - val_loss: 66360.5859 - val_mean_squared_error: 31053.1211
# Epoch 13/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 96754.0469 - mean_squared_error: 44444.4961 - val_loss: 62129.5195 - val_mean_squared_error: 28964.1855
# Epoch 14/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 90167.9141 - mean_squared_error: 41402.4297 - val_loss: 58548.9141 - val_mean_squared_error: 27315.9336
# Epoch 15/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 84932.4844 - mean_squared_error: 38928.5859 - val_loss: 53646.3359 - val_mean_squared_error: 24895.9531
# Epoch 16/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 78387.8750 - mean_squared_error: 35741.9375 - val_loss: 49272.7891 - val_mean_squared_error: 22774.9492
# Epoch 17/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 74896.6406 - mean_squared_error: 34061.0703 - val_loss: 47683.4531 - val_mean_squared_error: 22087.0391
# Epoch 18/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 75126.9375 - mean_squared_error: 34249.6211 - val_loss: 47926.1719 - val_mean_squared_error: 22222.9062
# Epoch 19/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 72684.3984 - mean_squared_error: 33140.1875 - val_loss: 46491.9570 - val_mean_squared_error: 21615.9922
# Epoch 20/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 66182.2734 - mean_squared_error: 30088.7480 - val_loss: 38463.6445 - val_mean_squared_error: 17656.8047
# Epoch 21/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 61170.6367 - mean_squared_error: 27637.8223 - val_loss: 38659.3047 - val_mean_squared_error: 17791.5117
# Epoch 22/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 59710.5508 - mean_squared_error: 27069.0625 - val_loss: 36427.3789 - val_mean_squared_error: 16764.5156
# Epoch 23/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 55446.6758 - mean_squared_error: 25005.3418 - val_loss: 33616.0547 - val_mean_squared_error: 15411.9434
# Epoch 24/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 54050.5742 - mean_squared_error: 24353.9512 - val_loss: 33057.6406 - val_mean_squared_error: 15169.9434
# Epoch 25/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 55510.5547 - mean_squared_error: 25087.6465 - val_loss: 38069.9141 - val_mean_squared_error: 17729.9824
# Epoch 26/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 53953.2422 - mean_squared_error: 24473.3691 - val_loss: 29326.6133 - val_mean_squared_error: 13385.9746
# Epoch 27/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 48445.5352 - mean_squared_error: 21746.4004 - val_loss: 28970.5781 - val_mean_squared_error: 13243.2715
# Epoch 28/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 47203.6914 - mean_squared_error: 21221.8008 - val_loss: 27003.7285 - val_mean_squared_error: 12301.8750
# Epoch 29/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 44543.7852 - mean_squared_error: 19932.3516 - val_loss: 26768.2266 - val_mean_squared_error: 12219.8770
# Epoch 30/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 43479.3164 - mean_squared_error: 19452.6172 - val_loss: 24986.4707 - val_mean_squared_error: 11354.3320
# Epoch 31/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 42240.0508 - mean_squared_error: 18883.9297 - val_loss: 24565.8203 - val_mean_squared_error: 11175.7656
# Epoch 32/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 40576.8711 - mean_squared_error: 18099.7070 - val_loss: 23416.6484 - val_mean_squared_error: 10626.6465
# Epoch 33/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 39532.3164 - mean_squared_error: 17617.2344 - val_loss: 22863.4238 - val_mean_squared_error: 10374.0928
# Epoch 34/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 38787.6211 - mean_squared_error: 17279.7441 - val_loss: 22363.5625 - val_mean_squared_error: 10145.8271
# Epoch 35/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 37862.1914 - mean_squared_error: 16856.3750 - val_loss: 21657.0840 - val_mean_squared_error: 9813.3818
# Epoch 36/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 37053.8594 - mean_squared_error: 16498.0117 - val_loss: 21399.1543 - val_mean_squared_error: 9700.6025
# Epoch 37/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 36430.8750 - mean_squared_error: 16197.9658 - val_loss: 20659.4121 - val_mean_squared_error: 9345.4941
# Epoch 38/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 35450.9805 - mean_squared_error: 15738.6494 - val_loss: 20226.3262 - val_mean_squared_error: 9142.1348
# Epoch 39/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 35160.0078 - mean_squared_error: 15622.5674 - val_loss: 20177.0215 - val_mean_squared_error: 9129.6318
# Epoch 40/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 34502.1523 - mean_squared_error: 15344.4434 - val_loss: 20309.2480 - val_mean_squared_error: 9204.0137
# Epoch 41/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 34401.7734 - mean_squared_error: 15267.6396 - val_loss: 19685.7520 - val_mean_squared_error: 8899.8672
# Epoch 42/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 33546.3828 - mean_squared_error: 14883.7744 - val_loss: 20011.0293 - val_mean_squared_error: 9070.7246
# Epoch 43/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 33348.6016 - mean_squared_error: 14779.8164 - val_loss: 20296.6016 - val_mean_squared_error: 9215.3281
# Epoch 44/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 34615.0117 - mean_squared_error: 15417.4160 - val_loss: 18771.4980 - val_mean_squared_error: 8461.0879
# Epoch 45/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 33411.6602 - mean_squared_error: 14876.1113 - val_loss: 18722.6504 - val_mean_squared_error: 8440.1338
# Epoch 46/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 33416.5820 - mean_squared_error: 14896.8506 - val_loss: 19069.1895 - val_mean_squared_error: 8612.6826
# Epoch 47/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 34921.4805 - mean_squared_error: 15552.6064 - val_loss: 21578.3535 - val_mean_squared_error: 9865.8750
# Epoch 48/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 39618.5000 - mean_squared_error: 17849.1016 - val_loss: 27867.3320 - val_mean_squared_error: 13017.5527
# Epoch 49/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 38661.3984 - mean_squared_error: 17422.9375 - val_loss: 19999.1406 - val_mean_squared_error: 9087.9717
# Epoch 50/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 33232.3438 - mean_squared_error: 14759.5752 - val_loss: 18511.0449 - val_mean_squared_error: 8347.1992
# Epoch 51/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 31391.9785 - mean_squared_error: 13880.2979 - val_loss: 17912.8242 - val_mean_squared_error: 8053.4976
# Epoch 52/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 30502.1602 - mean_squared_error: 13448.3799 - val_loss: 17460.9863 - val_mean_squared_error: 7832.6772
# Epoch 53/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 30108.2129 - mean_squared_error: 13252.7471 - val_loss: 18098.4277 - val_mean_squared_error: 8155.8354
# Epoch 54/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 29980.9844 - mean_squared_error: 13203.5742 - val_loss: 17319.8809 - val_mean_squared_error: 7773.0459
# Epoch 55/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 29309.8457 - mean_squared_error: 12876.5186 - val_loss: 17018.7188 - val_mean_squared_error: 7627.9014
# Epoch 56/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 29050.4941 - mean_squared_error: 12759.9287 - val_loss: 17275.4219 - val_mean_squared_error: 7760.6738
# Epoch 57/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 28893.2129 - mean_squared_error: 12692.2402 - val_loss: 16723.6328 - val_mean_squared_error: 7488.4429
# Epoch 58/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 28532.2637 - mean_squared_error: 12522.1201 - val_loss: 16578.9355 - val_mean_squared_error: 7420.5845
# Epoch 59/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 28322.9277 - mean_squared_error: 12425.0400 - val_loss: 16519.5645 - val_mean_squared_error: 7394.4678
# Epoch 60/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 28136.8691 - mean_squared_error: 12340.6006 - val_loss: 16293.0576 - val_mean_squared_error: 7284.5635
# Epoch 61/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27921.3652 - mean_squared_error: 12240.6631 - val_loss: 16420.4805 - val_mean_squared_error: 7351.4805
# Epoch 62/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 27827.3574 - mean_squared_error: 12200.2666 - val_loss: 16089.7734 - val_mean_squared_error: 7189.6626
# Epoch 63/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27621.4082 - mean_squared_error: 12104.8164 - val_loss: 16408.7012 - val_mean_squared_error: 7352.6538
# Epoch 64/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 27613.8457 - mean_squared_error: 12105.0645 - val_loss: 15849.7422 - val_mean_squared_error: 7076.1660
# Epoch 65/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27469.6504 - mean_squared_error: 12037.9668 - val_loss: 16578.8945 - val_mean_squared_error: 7444.0669
# Epoch 66/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27806.0527 - mean_squared_error: 12203.2705 - val_loss: 15853.4424 - val_mean_squared_error: 7083.3066
# Epoch 67/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 28254.3574 - mean_squared_error: 12423.9258 - val_loss: 17407.1348 - val_mean_squared_error: 7862.8892
# Epoch 68/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 30001.4785 - mean_squared_error: 13261.6953 - val_loss: 17511.9844 - val_mean_squared_error: 7915.1245
# Epoch 69/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 32445.8730 - mean_squared_error: 14415.8311 - val_loss: 25025.5645 - val_mean_squared_error: 11668.5029
# Epoch 70/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 39510.1641 - mean_squared_error: 18118.9082 - val_loss: 28695.5234 - val_mean_squared_error: 13505.3047
# Epoch 71/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 39002.1562 - mean_squared_error: 17780.0684 - val_loss: 18762.0215 - val_mean_squared_error: 8532.8350
# Epoch 72/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 34077.6641 - mean_squared_error: 15267.3730 - val_loss: 18906.8984 - val_mean_squared_error: 8607.1719
# Epoch 73/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 29738.0645 - mean_squared_error: 13138.8652 - val_loss: 20976.7168 - val_mean_squared_error: 9646.9365
# Epoch 74/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 29517.6621 - mean_squared_error: 13080.2920 - val_loss: 16466.6816 - val_mean_squared_error: 7395.5522
# Epoch 75/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27468.4121 - mean_squared_error: 12070.5391 - val_loss: 15857.2559 - val_mean_squared_error: 7093.1768
# Epoch 76/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 26945.9727 - mean_squared_error: 11808.3760 - val_loss: 15547.7480 - val_mean_squared_error: 6942.9434
# Epoch 77/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 26697.2363 - mean_squared_error: 11693.2881 - val_loss: 15584.1631 - val_mean_squared_error: 6965.8198
# Epoch 78/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 26491.0430 - mean_squared_error: 11596.8662 - val_loss: 15696.9150 - val_mean_squared_error: 7024.5708
# Epoch 79/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 26331.4180 - mean_squared_error: 11521.9492 - val_loss: 15422.2070 - val_mean_squared_error: 6890.8711
# Epoch 80/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 26124.2344 - mean_squared_error: 11429.4199 - val_loss: 15222.2871 - val_mean_squared_error: 6793.5205
# Epoch 81/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 25942.1797 - mean_squared_error: 11343.1074 - val_loss: 15124.2041 - val_mean_squared_error: 6748.1323
# Epoch 82/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 25819.3027 - mean_squared_error: 11286.7695 - val_loss: 14973.2646 - val_mean_squared_error: 6674.3281
# Epoch 83/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25671.9316 - mean_squared_error: 11220.3320 - val_loss: 15001.5312 - val_mean_squared_error: 6689.5986
# Epoch 84/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 25607.3711 - mean_squared_error: 11188.4658 - val_loss: 14861.9072 - val_mean_squared_error: 6621.9297
# Epoch 85/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 25491.6309 - mean_squared_error: 11137.0000 - val_loss: 14817.0508 - val_mean_squared_error: 6601.1841
# Epoch 86/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 25399.1582 - mean_squared_error: 11094.7695 - val_loss: 14891.4424 - val_mean_squared_error: 6640.3828
# Epoch 87/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 25441.8281 - mean_squared_error: 11114.8711 - val_loss: 14767.5967 - val_mean_squared_error: 6579.6992
# Epoch 88/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25282.9844 - mean_squared_error: 11047.6035 - val_loss: 14852.4062 - val_mean_squared_error: 6623.1514
# Epoch 89/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 25236.6230 - mean_squared_error: 11020.8623 - val_loss: 14688.7676 - val_mean_squared_error: 6543.4424
# Epoch 90/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 25210.4473 - mean_squared_error: 11010.8779 - val_loss: 14674.6455 - val_mean_squared_error: 6537.2783
# Epoch 91/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25178.1758 - mean_squared_error: 11002.6846 - val_loss: 15134.5977 - val_mean_squared_error: 6768.7358
# Epoch 92/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25386.0645 - mean_squared_error: 11099.3193 - val_loss: 14957.8066 - val_mean_squared_error: 6681.3438
# Epoch 93/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 25120.4863 - mean_squared_error: 10983.7578 - val_loss: 14570.4766 - val_mean_squared_error: 6489.0430
# Epoch 94/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25004.3672 - mean_squared_error: 10921.3643 - val_loss: 14865.7197 - val_mean_squared_error: 6638.3799
# Epoch 95/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25281.5137 - mean_squared_error: 11057.1748 - val_loss: 14894.8574 - val_mean_squared_error: 6652.7695
# Epoch 96/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 25322.2305 - mean_squared_error: 11092.7314 - val_loss: 15371.2705 - val_mean_squared_error: 6893.2070
# Epoch 97/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 25320.3516 - mean_squared_error: 11080.5693 - val_loss: 15018.8379 - val_mean_squared_error: 6717.0454
# Epoch 98/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 25174.2734 - mean_squared_error: 11014.0732 - val_loss: 14520.6025 - val_mean_squared_error: 6468.7822
# Epoch 99/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25571.7305 - mean_squared_error: 11209.8047 - val_loss: 16359.3369 - val_mean_squared_error: 7389.0000
# Epoch 100/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 26808.7695 - mean_squared_error: 11820.3291 - val_loss: 16389.2656 - val_mean_squared_error: 7403.8291
# Epoch 101/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 26645.6562 - mean_squared_error: 11764.3848 - val_loss: 15934.4844 - val_mean_squared_error: 7180.1431
# Epoch 102/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 26077.3848 - mean_squared_error: 11464.0430 - val_loss: 16020.4805 - val_mean_squared_error: 7221.4863
# Epoch 103/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 26356.8438 - mean_squared_error: 11599.3018 - val_loss: 16396.3418 - val_mean_squared_error: 7410.2368
# Epoch 104/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25664.6406 - mean_squared_error: 11282.7559 - val_loss: 14915.3047 - val_mean_squared_error: 6670.3418
# Epoch 105/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 25129.7031 - mean_squared_error: 11014.5488 - val_loss: 14771.3291 - val_mean_squared_error: 6601.7549
# Epoch 106/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 25051.0547 - mean_squared_error: 10968.0342 - val_loss: 14903.6064 - val_mean_squared_error: 6665.7295
# Epoch 107/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 25749.9258 - mean_squared_error: 11294.4209 - val_loss: 15046.3066 - val_mean_squared_error: 6741.7295
# Epoch 108/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 26318.8281 - mean_squared_error: 11573.9561 - val_loss: 16483.2578 - val_mean_squared_error: 7456.8931
# Epoch 109/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 27051.8594 - mean_squared_error: 11952.3076 - val_loss: 17461.3223 - val_mean_squared_error: 7949.5811
# Epoch 110/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 27112.5000 - mean_squared_error: 12015.6250 - val_loss: 15829.8301 - val_mean_squared_error: 7134.5044
# Epoch 111/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 25379.8184 - mean_squared_error: 11160.8955 - val_loss: 14299.4473 - val_mean_squared_error: 6371.7158
# Epoch 112/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 24625.4238 - mean_squared_error: 10781.1377 - val_loss: 14155.5898 - val_mean_squared_error: 6301.0615
# Epoch 113/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 24473.7363 - mean_squared_error: 10698.7051 - val_loss: 14223.8418 - val_mean_squared_error: 6334.2920
# Epoch 114/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 24543.5000 - mean_squared_error: 10719.4453 - val_loss: 13864.1221 - val_mean_squared_error: 6159.1270
# Epoch 115/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 24335.8438 - mean_squared_error: 10624.4375 - val_loss: 14430.3682 - val_mean_squared_error: 6439.8628
# Epoch 116/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 24268.3145 - mean_squared_error: 10599.1982 - val_loss: 14047.4473 - val_mean_squared_error: 6252.1265
# Epoch 117/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 24112.0332 - mean_squared_error: 10523.5771 - val_loss: 14218.0869 - val_mean_squared_error: 6337.1851
# Epoch 118/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 23926.1934 - mean_squared_error: 10438.5283 - val_loss: 13893.9336 - val_mean_squared_error: 6177.7910
# Epoch 119/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 23887.0391 - mean_squared_error: 10426.1211 - val_loss: 14383.6074 - val_mean_squared_error: 6423.3320
# Epoch 120/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 23890.1152 - mean_squared_error: 10427.2705 - val_loss: 13918.6084 - val_mean_squared_error: 6191.8745
# Epoch 121/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 23794.7910 - mean_squared_error: 10387.3467 - val_loss: 14317.8457 - val_mean_squared_error: 6393.1323
# Epoch 122/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 23748.1895 - mean_squared_error: 10363.9014 - val_loss: 14016.7695 - val_mean_squared_error: 6242.6562
# Epoch 123/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23870.4902 - mean_squared_error: 10421.9619 - val_loss: 14675.3828 - val_mean_squared_error: 6572.6562
# Epoch 124/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 23759.1582 - mean_squared_error: 10382.8525 - val_loss: 13969.6094 - val_mean_squared_error: 6220.0015
# Epoch 125/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 23660.8574 - mean_squared_error: 10324.9893 - val_loss: 14326.2012 - val_mean_squared_error: 6400.0054
# Epoch 126/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 23716.3730 - mean_squared_error: 10354.2383 - val_loss: 14273.9912 - val_mean_squared_error: 6370.6191
# Epoch 127/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23905.6133 - mean_squared_error: 10453.8398 - val_loss: 14853.6426 - val_mean_squared_error: 6665.8335
# Epoch 128/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 23902.3457 - mean_squared_error: 10447.7627 - val_loss: 14379.0654 - val_mean_squared_error: 6423.8213
# Epoch 129/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 23612.6992 - mean_squared_error: 10311.0967 - val_loss: 13796.4482 - val_mean_squared_error: 6139.6284
# Epoch 130/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 23550.2441 - mean_squared_error: 10276.9922 - val_loss: 14087.8057 - val_mean_squared_error: 6281.8975
# Epoch 131/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 24074.8066 - mean_squared_error: 10529.8076 - val_loss: 14399.6465 - val_mean_squared_error: 6439.8457
# Epoch 132/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 24824.7383 - mean_squared_error: 10901.3203 - val_loss: 15431.1230 - val_mean_squared_error: 6954.8574
# Epoch 133/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 26485.6621 - mean_squared_error: 11675.1299 - val_loss: 17309.0957 - val_mean_squared_error: 7892.6582
# Epoch 134/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 28348.6133 - mean_squared_error: 12582.7988 - val_loss: 20832.2578 - val_mean_squared_error: 9653.9834
# Epoch 135/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 31058.5820 - mean_squared_error: 14017.4307 - val_loss: 24618.6973 - val_mean_squared_error: 11542.9492
# Epoch 136/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 30599.5234 - mean_squared_error: 13768.6455 - val_loss: 16038.3613 - val_mean_squared_error: 7255.0747
# Epoch 137/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 26711.2227 - mean_squared_error: 11814.4336 - val_loss: 15591.8340 - val_mean_squared_error: 7031.4976
# Epoch 138/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 25516.8633 - mean_squared_error: 11246.7607 - val_loss: 14136.0215 - val_mean_squared_error: 6308.4888
# Epoch 139/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 24631.4023 - mean_squared_error: 10802.6270 - val_loss: 14488.3711 - val_mean_squared_error: 6480.0830
# Epoch 140/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 24179.0039 - mean_squared_error: 10586.8916 - val_loss: 13693.1055 - val_mean_squared_error: 6093.2446
# Epoch 141/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 23727.6680 - mean_squared_error: 10370.1719 - val_loss: 13885.6260 - val_mean_squared_error: 6187.0830
# Epoch 142/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 23186.3359 - mean_squared_error: 10113.1553 - val_loss: 13398.3682 - val_mean_squared_error: 5948.3013
# Epoch 143/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 23001.0566 - mean_squared_error: 10024.0264 - val_loss: 13277.7539 - val_mean_squared_error: 5890.8345
# Epoch 144/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 22778.9043 - mean_squared_error: 9917.9434 - val_loss: 13215.1338 - val_mean_squared_error: 5861.6553
# Epoch 145/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 22715.9062 - mean_squared_error: 9889.1904 - val_loss: 13199.5029 - val_mean_squared_error: 5852.8096
# Epoch 146/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 22567.5645 - mean_squared_error: 9817.0801 - val_loss: 13175.4746 - val_mean_squared_error: 5841.8037
# Epoch 147/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 22481.2070 - mean_squared_error: 9777.7744 - val_loss: 13147.9355 - val_mean_squared_error: 5830.4004
# Epoch 148/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22391.9863 - mean_squared_error: 9733.8398 - val_loss: 13182.2900 - val_mean_squared_error: 5846.9595
# Epoch 149/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22378.5723 - mean_squared_error: 9729.7217 - val_loss: 13162.7695 - val_mean_squared_error: 5839.6201
# Epoch 150/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 22318.2773 - mean_squared_error: 9703.1250 - val_loss: 13036.4287 - val_mean_squared_error: 5776.7803
# Epoch 151/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 22245.7363 - mean_squared_error: 9668.3027 - val_loss: 12993.5254 - val_mean_squared_error: 5755.7412
# Epoch 152/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22188.1836 - mean_squared_error: 9641.3467 - val_loss: 13015.4707 - val_mean_squared_error: 5768.2158
# Epoch 153/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 22167.1133 - mean_squared_error: 9635.5400 - val_loss: 12970.9043 - val_mean_squared_error: 5746.5059
# Epoch 154/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22170.5059 - mean_squared_error: 9635.3037 - val_loss: 13016.2227 - val_mean_squared_error: 5770.7637
# Epoch 155/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22189.7793 - mean_squared_error: 9649.6309 - val_loss: 13057.5254 - val_mean_squared_error: 5789.8110
# Epoch 156/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22420.8926 - mean_squared_error: 9759.4482 - val_loss: 13297.6250 - val_mean_squared_error: 5913.5752
# Epoch 157/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22835.5449 - mean_squared_error: 9962.4707 - val_loss: 13638.0303 - val_mean_squared_error: 6077.4912
# Epoch 158/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23936.7539 - mean_squared_error: 10483.9561 - val_loss: 15248.8018 - val_mean_squared_error: 6887.4590
# Epoch 159/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 26070.2363 - mean_squared_error: 11505.5732 - val_loss: 17281.8203 - val_mean_squared_error: 7893.9229
# Epoch 160/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27607.2129 - mean_squared_error: 12249.4043 - val_loss: 19660.7969 - val_mean_squared_error: 9087.2197
# Epoch 161/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 29886.8340 - mean_squared_error: 13428.6191 - val_loss: 23755.9297 - val_mean_squared_error: 11128.4131
# Epoch 162/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 29154.7891 - mean_squared_error: 13103.1270 - val_loss: 14877.3271 - val_mean_squared_error: 6696.7358
# Epoch 163/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 24644.5488 - mean_squared_error: 10845.7930 - val_loss: 13755.2461 - val_mean_squared_error: 6134.3965
# Epoch 164/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23412.1367 - mean_squared_error: 10238.6699 - val_loss: 13816.9590 - val_mean_squared_error: 6166.9775
# Epoch 165/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23530.3320 - mean_squared_error: 10291.1885 - val_loss: 13972.9551 - val_mean_squared_error: 6240.5254
# Epoch 166/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23360.7793 - mean_squared_error: 10204.8994 - val_loss: 13918.9561 - val_mean_squared_error: 6223.5610
# Epoch 167/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23772.3984 - mean_squared_error: 10410.0928 - val_loss: 14382.0146 - val_mean_squared_error: 6452.7017
# Epoch 168/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23574.2266 - mean_squared_error: 10337.5615 - val_loss: 14472.5996 - val_mean_squared_error: 6502.7275
# Epoch 169/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23340.5762 - mean_squared_error: 10232.0303 - val_loss: 13545.6074 - val_mean_squared_error: 6038.5713
# Epoch 170/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22382.0820 - mean_squared_error: 9763.7783 - val_loss: 13009.0635 - val_mean_squared_error: 5776.1143
# Epoch 171/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 22090.3652 - mean_squared_error: 9620.5820 - val_loss: 12825.3467 - val_mean_squared_error: 5684.5972
# Epoch 172/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22022.4414 - mean_squared_error: 9577.5996 - val_loss: 12965.5137 - val_mean_squared_error: 5754.1689
# Epoch 173/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22021.4316 - mean_squared_error: 9578.0830 - val_loss: 13070.6484 - val_mean_squared_error: 5809.4194
# Epoch 174/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22049.7656 - mean_squared_error: 9598.6973 - val_loss: 12899.6016 - val_mean_squared_error: 5725.8428
# Epoch 175/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 21796.9492 - mean_squared_error: 9477.2578 - val_loss: 12794.3291 - val_mean_squared_error: 5675.3828
# Epoch 176/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21698.0469 - mean_squared_error: 9431.1582 - val_loss: 12870.3262 - val_mean_squared_error: 5712.1392
# Epoch 177/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 21547.8105 - mean_squared_error: 9363.9326 - val_loss: 12656.4121 - val_mean_squared_error: 5606.3389
# Epoch 178/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21426.7656 - mean_squared_error: 9303.4053 - val_loss: 12681.5918 - val_mean_squared_error: 5619.6758
# Epoch 179/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 21332.2988 - mean_squared_error: 9261.8262 - val_loss: 12608.6973 - val_mean_squared_error: 5583.9980
# Epoch 180/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 21326.9258 - mean_squared_error: 9258.6045 - val_loss: 12561.1826 - val_mean_squared_error: 5561.1914
# Epoch 181/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21254.6621 - mean_squared_error: 9225.7471 - val_loss: 12741.2031 - val_mean_squared_error: 5651.3218
# Epoch 182/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 21281.8340 - mean_squared_error: 9241.2100 - val_loss: 12539.9199 - val_mean_squared_error: 5554.6782
# Epoch 183/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 21196.2832 - mean_squared_error: 9199.5332 - val_loss: 12603.5732 - val_mean_squared_error: 5583.8062
# Epoch 184/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 21135.2305 - mean_squared_error: 9171.8643 - val_loss: 12507.2471 - val_mean_squared_error: 5537.5586
# Epoch 185/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 21149.3633 - mean_squared_error: 9179.2061 - val_loss: 12476.9092 - val_mean_squared_error: 5525.3047
# Epoch 186/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 21112.3418 - mean_squared_error: 9161.9590 - val_loss: 12672.3818 - val_mean_squared_error: 5618.2861
# Epoch 187/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 21283.9512 - mean_squared_error: 9245.4639 - val_loss: 12637.8193 - val_mean_squared_error: 5608.1011
# Epoch 188/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 21385.0469 - mean_squared_error: 9296.0244 - val_loss: 12992.1318 - val_mean_squared_error: 5777.3745
# Epoch 189/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 21976.4531 - mean_squared_error: 9580.2920 - val_loss: 13408.7314 - val_mean_squared_error: 5994.9644
# Epoch 190/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 22676.5254 - mean_squared_error: 9913.2139 - val_loss: 14495.9746 - val_mean_squared_error: 6521.6758
# Epoch 191/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 24117.8418 - mean_squared_error: 10594.2852 - val_loss: 17271.6367 - val_mean_squared_error: 7925.9121
# Epoch 192/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 26340.6641 - mean_squared_error: 11673.8945 - val_loss: 19891.6680 - val_mean_squared_error: 9217.9795
# Epoch 193/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 26945.3848 - mean_squared_error: 11995.6855 - val_loss: 17607.8770 - val_mean_squared_error: 8085.8291
# Epoch 194/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 24969.5801 - mean_squared_error: 11083.2295 - val_loss: 16974.4316 - val_mean_squared_error: 7761.5308
# Epoch 195/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 23539.7734 - mean_squared_error: 10375.0625 - val_loss: 13006.9746 - val_mean_squared_error: 5785.4624
# Epoch 196/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 22379.2539 - mean_squared_error: 9784.5195 - val_loss: 13612.4248 - val_mean_squared_error: 6093.4482
# Epoch 197/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 22574.1250 - mean_squared_error: 9877.9385 - val_loss: 14225.1299 - val_mean_squared_error: 6394.2500
# Epoch 198/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 22881.4473 - mean_squared_error: 10033.3525 - val_loss: 14016.1055 - val_mean_squared_error: 6294.6602
# Epoch 199/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 22441.8691 - mean_squared_error: 9828.4971 - val_loss: 12928.5156 - val_mean_squared_error: 5758.7061
# Epoch 200/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 21594.1426 - mean_squared_error: 9409.8730 - val_loss: 12884.3506 - val_mean_squared_error: 5731.7354
# Epoch 201/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 21482.2344 - mean_squared_error: 9362.7812 - val_loss: 13183.8281 - val_mean_squared_error: 5882.3755
# Epoch 202/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 21412.1250 - mean_squared_error: 9335.1123 - val_loss: 12493.4727 - val_mean_squared_error: 5543.2798
# Epoch 203/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 20929.1191 - mean_squared_error: 9097.0068 - val_loss: 12475.2080 - val_mean_squared_error: 5533.4902
# Epoch 204/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 20922.6328 - mean_squared_error: 9091.5615 - val_loss: 12344.1738 - val_mean_squared_error: 5468.9966
# Epoch 205/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 20836.6445 - mean_squared_error: 9051.1270 - val_loss: 12835.6494 - val_mean_squared_error: 5713.5439
# Epoch 206/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 20988.0527 - mean_squared_error: 9133.5830 - val_loss: 12310.2471 - val_mean_squared_error: 5456.7891
# Epoch 207/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 20702.7285 - mean_squared_error: 8988.7422 - val_loss: 12297.0820 - val_mean_squared_error: 5447.6201
# Epoch 208/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20591.4297 - mean_squared_error: 8935.4971 - val_loss: 12783.8955 - val_mean_squared_error: 5686.1836
# Epoch 209/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21007.6758 - mean_squared_error: 9136.5781 - val_loss: 12753.5742 - val_mean_squared_error: 5681.4248
# Epoch 210/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21017.4160 - mean_squared_error: 9142.7764 - val_loss: 13695.4238 - val_mean_squared_error: 6140.3813
# Epoch 211/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 21547.7715 - mean_squared_error: 9401.5264 - val_loss: 13102.3184 - val_mean_squared_error: 5858.4951
# Epoch 212/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21552.6836 - mean_squared_error: 9398.7061 - val_loss: 13951.3359 - val_mean_squared_error: 6271.7915
# Epoch 213/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21993.4180 - mean_squared_error: 9617.0498 - val_loss: 13867.7109 - val_mean_squared_error: 6238.3721
# Epoch 214/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21877.4258 - mean_squared_error: 9582.0225 - val_loss: 14326.6924 - val_mean_squared_error: 6459.7939
# Epoch 215/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 21834.3066 - mean_squared_error: 9552.3516 - val_loss: 12912.6172 - val_mean_squared_error: 5763.2666
# Epoch 216/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21240.3379 - mean_squared_error: 9261.8887 - val_loss: 14665.7021 - val_mean_squared_error: 6626.1279
# Epoch 217/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21886.2266 - mean_squared_error: 9591.0381 - val_loss: 13622.7578 - val_mean_squared_error: 6121.9595
# Epoch 218/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21200.4551 - mean_squared_error: 9250.2324 - val_loss: 13415.8398 - val_mean_squared_error: 6008.0059
# Epoch 219/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20946.6250 - mean_squared_error: 9126.3174 - val_loss: 12631.6768 - val_mean_squared_error: 5621.5713
# Epoch 220/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20665.2910 - mean_squared_error: 8997.9766 - val_loss: 12482.0205 - val_mean_squared_error: 5547.2529
# Epoch 221/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 20453.9043 - mean_squared_error: 8892.6816 - val_loss: 12161.6133 - val_mean_squared_error: 5387.1143
# Epoch 222/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20435.2109 - mean_squared_error: 8876.9736 - val_loss: 12254.4951 - val_mean_squared_error: 5437.4717
# Epoch 223/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20618.5430 - mean_squared_error: 8965.6211 - val_loss: 12509.0459 - val_mean_squared_error: 5559.8594
# Epoch 224/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20831.2188 - mean_squared_error: 9067.4404 - val_loss: 12339.0371 - val_mean_squared_error: 5481.4248
# Epoch 225/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20851.4258 - mean_squared_error: 9075.0127 - val_loss: 13184.0078 - val_mean_squared_error: 5892.0254
# Epoch 226/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21715.8828 - mean_squared_error: 9487.2715 - val_loss: 13726.1953 - val_mean_squared_error: 6179.1538
# Epoch 227/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22456.3105 - mean_squared_error: 9839.0527 - val_loss: 15843.8477 - val_mean_squared_error: 7215.3745
# Epoch 228/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23682.2031 - mean_squared_error: 10424.8936 - val_loss: 16493.0488 - val_mean_squared_error: 7561.9614
# Epoch 229/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23824.6484 - mean_squared_error: 10510.4932 - val_loss: 16702.9512 - val_mean_squared_error: 7654.4727
# Epoch 230/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 23188.6738 - mean_squared_error: 10227.1416 - val_loss: 13227.9316 - val_mean_squared_error: 5918.6729
# Epoch 231/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 21037.1074 - mean_squared_error: 9187.0234 - val_loss: 12793.0967 - val_mean_squared_error: 5709.3164
# Epoch 232/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20659.5098 - mean_squared_error: 8992.4072 - val_loss: 12561.3008 - val_mean_squared_error: 5591.0986
# Epoch 233/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 20306.5488 - mean_squared_error: 8832.5801 - val_loss: 12057.7021 - val_mean_squared_error: 5342.2769
# Epoch 234/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20085.8398 - mean_squared_error: 8714.5635 - val_loss: 12334.3887 - val_mean_squared_error: 5478.7891
# Epoch 235/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 20537.9121 - mean_squared_error: 8931.7324 - val_loss: 12414.7373 - val_mean_squared_error: 5523.7949
# Epoch 236/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20553.1719 - mean_squared_error: 8947.4609 - val_loss: 13274.4541 - val_mean_squared_error: 5948.4106
# Epoch 237/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 20581.0703 - mean_squared_error: 8960.4990 - val_loss: 12301.1973 - val_mean_squared_error: 5471.5166
# Epoch 238/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 19982.6602 - mean_squared_error: 8676.1865 - val_loss: 12814.1406 - val_mean_squared_error: 5716.6484
# Epoch 239/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 20218.4648 - mean_squared_error: 8788.6035 - val_loss: 11975.6250 - val_mean_squared_error: 5311.1182
# Epoch 240/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 19816.9609 - mean_squared_error: 8595.9424 - val_loss: 12602.4961 - val_mean_squared_error: 5613.5264
# Epoch 241/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 19987.9062 - mean_squared_error: 8679.8984 - val_loss: 11962.7959 - val_mean_squared_error: 5305.2100
# Epoch 242/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 19678.2285 - mean_squared_error: 8530.2607 - val_loss: 12436.7559 - val_mean_squared_error: 5533.5713
# Epoch 243/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 19799.2070 - mean_squared_error: 8590.3838 - val_loss: 11841.3682 - val_mean_squared_error: 5241.5674
# Epoch 244/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 19515.3203 - mean_squared_error: 8453.9414 - val_loss: 12053.2041 - val_mean_squared_error: 5345.6685
# Epoch 245/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 19640.3027 - mean_squared_error: 8516.1768 - val_loss: 11739.8867 - val_mean_squared_error: 5193.0244
# Epoch 246/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 19472.6523 - mean_squared_error: 8437.8701 - val_loss: 12191.8350 - val_mean_squared_error: 5413.2544
# Epoch 247/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 19806.7266 - mean_squared_error: 8599.0986 - val_loss: 11878.2559 - val_mean_squared_error: 5265.5010
# Epoch 248/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 19794.9961 - mean_squared_error: 8592.1768 - val_loss: 12741.9707 - val_mean_squared_error: 5684.0332
# Epoch 249/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20517.1309 - mean_squared_error: 8940.8506 - val_loss: 12595.5283 - val_mean_squared_error: 5625.1294
# Epoch 250/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20884.5078 - mean_squared_error: 9109.4424 - val_loss: 14227.5537 - val_mean_squared_error: 6423.0879
# Epoch 251/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22417.1504 - mean_squared_error: 9842.0557 - val_loss: 14847.4590 - val_mean_squared_error: 6750.7695
# Epoch 252/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 23640.7578 - mean_squared_error: 10425.5273 - val_loss: 17782.0918 - val_mean_squared_error: 8199.9004
# Epoch 253/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 24442.2324 - mean_squared_error: 10835.8975 - val_loss: 16323.3301 - val_mean_squared_error: 7485.8594
# Epoch 254/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 23204.3711 - mean_squared_error: 10287.6104 - val_loss: 17680.7070 - val_mean_squared_error: 8152.8638
# Epoch 255/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22842.2344 - mean_squared_error: 10119.8398 - val_loss: 12448.2402 - val_mean_squared_error: 5542.3867
# Epoch 256/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 20330.8750 - mean_squared_error: 8872.1562 - val_loss: 12664.1309 - val_mean_squared_error: 5656.1372
# Epoch 257/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 20253.2773 - mean_squared_error: 8827.6230 - val_loss: 13488.2578 - val_mean_squared_error: 6063.2148
# Epoch 258/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 20985.1953 - mean_squared_error: 9167.2500 - val_loss: 13014.7168 - val_mean_squared_error: 5835.9307
# Epoch 259/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20402.9688 - mean_squared_error: 8901.5029 - val_loss: 13400.0039 - val_mean_squared_error: 6019.6191
# Epoch 260/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 20135.2383 - mean_squared_error: 8775.6113 - val_loss: 11864.5996 - val_mean_squared_error: 5262.6943
# Epoch 261/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 19277.0508 - mean_squared_error: 8361.3965 - val_loss: 11841.9551 - val_mean_squared_error: 5247.8169
# Epoch 262/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 19056.8594 - mean_squared_error: 8254.8301 - val_loss: 12397.1270 - val_mean_squared_error: 5526.3672
# Epoch 263/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 19343.2910 - mean_squared_error: 8396.2969 - val_loss: 12082.8750 - val_mean_squared_error: 5375.1348
# Epoch 264/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 19150.1367 - mean_squared_error: 8302.9375 - val_loss: 12297.6348 - val_mean_squared_error: 5476.8496
# Epoch 265/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 19237.6992 - mean_squared_error: 8351.3096 - val_loss: 11570.3086 - val_mean_squared_error: 5118.7480
# Epoch 266/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 18858.0254 - mean_squared_error: 8165.1367 - val_loss: 11649.9902 - val_mean_squared_error: 5156.6064
# Epoch 267/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 18881.4316 - mean_squared_error: 8177.7490 - val_loss: 11866.9229 - val_mean_squared_error: 5263.8506
# Epoch 268/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 18977.3789 - mean_squared_error: 8221.9609 - val_loss: 11717.3506 - val_mean_squared_error: 5191.1270
# Epoch 269/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 18920.0059 - mean_squared_error: 8195.9961 - val_loss: 11932.1201 - val_mean_squared_error: 5297.5503
# Epoch 270/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 18894.5938 - mean_squared_error: 8187.2061 - val_loss: 11843.2754 - val_mean_squared_error: 5255.3618
# Epoch 271/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 18869.9023 - mean_squared_error: 8175.8232 - val_loss: 11613.8066 - val_mean_squared_error: 5142.3311
# Epoch 272/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 18717.7305 - mean_squared_error: 8103.9849 - val_loss: 12182.9541 - val_mean_squared_error: 5422.8838
# Epoch 273/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 19023.2285 - mean_squared_error: 8250.6914 - val_loss: 11710.8799 - val_mean_squared_error: 5194.7695
# Epoch 274/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 18829.3027 - mean_squared_error: 8159.8706 - val_loss: 12535.0166 - val_mean_squared_error: 5596.3418
# Epoch 275/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 19195.0039 - mean_squared_error: 8338.6543 - val_loss: 12132.1455 - val_mean_squared_error: 5401.8506
# Epoch 276/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 19124.6074 - mean_squared_error: 8304.1543 - val_loss: 13003.3301 - val_mean_squared_error: 5830.6528
# Epoch 277/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 19535.3555 - mean_squared_error: 8503.4883 - val_loss: 12378.7910 - val_mean_squared_error: 5528.9609
# Epoch 278/1500
# ...
# Epoch 597/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12828.2803 - mean_squared_error: 5522.6396 - val_loss: 9732.8145 - val_mean_squared_error: 4292.7871
# Epoch 598/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12469.8857 - mean_squared_error: 5348.3677 - val_loss: 9860.4248 - val_mean_squared_error: 4352.2749
# Epoch 599/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12558.8467 - mean_squared_error: 5391.3789 - val_loss: 9664.7764 - val_mean_squared_error: 4269.0684
# Epoch 600/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 12471.3369 - mean_squared_error: 5352.3320 - val_loss: 9523.5703 - val_mean_squared_error: 4194.6714
# Epoch 601/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12395.6201 - mean_squared_error: 5317.4668 - val_loss: 9627.9951 - val_mean_squared_error: 4248.7886
# Epoch 602/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12238.2285 - mean_squared_error: 5246.4995 - val_loss: 9757.2295 - val_mean_squared_error: 4308.6782
# Epoch 603/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12183.0977 - mean_squared_error: 5223.3511 - val_loss: 9699.0635 - val_mean_squared_error: 4283.5405
# Epoch 604/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12204.5586 - mean_squared_error: 5236.4062 - val_loss: 9726.5068 - val_mean_squared_error: 4290.2437
# Epoch 605/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12252.1611 - mean_squared_error: 5257.1562 - val_loss: 9773.5098 - val_mean_squared_error: 4314.7490
# Epoch 606/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12227.6436 - mean_squared_error: 5244.7788 - val_loss: 9718.4268 - val_mean_squared_error: 4291.8115
# Epoch 607/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12476.3242 - mean_squared_error: 5370.5029 - val_loss: 10276.4492 - val_mean_squared_error: 4567.8408
# Epoch 608/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12580.2510 - mean_squared_error: 5405.2056 - val_loss: 9945.2881 - val_mean_squared_error: 4390.8530
# Epoch 609/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12554.1934 - mean_squared_error: 5392.2891 - val_loss: 10057.5605 - val_mean_squared_error: 4455.7334
# Epoch 610/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12709.7910 - mean_squared_error: 5482.9419 - val_loss: 10346.4775 - val_mean_squared_error: 4608.6191
# Epoch 611/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12892.7363 - mean_squared_error: 5562.1719 - val_loss: 10064.9727 - val_mean_squared_error: 4450.5303
# Epoch 612/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12767.9277 - mean_squared_error: 5518.6602 - val_loss: 10356.8057 - val_mean_squared_error: 4598.0547
# Epoch 613/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12897.9121 - mean_squared_error: 5580.5562 - val_loss: 12340.7207 - val_mean_squared_error: 5601.1289
# Epoch 614/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 15186.1846 - mean_squared_error: 6669.0068 - val_loss: 10229.7529 - val_mean_squared_error: 4530.3125
# Epoch 615/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13669.1260 - mean_squared_error: 5990.2354 - val_loss: 11896.8184 - val_mean_squared_error: 5357.2607
# Epoch 616/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13851.3018 - mean_squared_error: 6046.3076 - val_loss: 13916.9561 - val_mean_squared_error: 6361.8477
# Epoch 617/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 15079.8867 - mean_squared_error: 6600.3320 - val_loss: 10638.6406 - val_mean_squared_error: 4723.2646
# Epoch 618/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13856.6826 - mean_squared_error: 6036.6401 - val_loss: 10618.9258 - val_mean_squared_error: 4719.9790
# Epoch 619/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13991.5850 - mean_squared_error: 6138.6440 - val_loss: 13058.0742 - val_mean_squared_error: 5939.1045
# Epoch 620/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14747.9971 - mean_squared_error: 6468.2192 - val_loss: 10964.0596 - val_mean_squared_error: 4900.1396
# Epoch 621/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13606.9082 - mean_squared_error: 5880.5903 - val_loss: 11601.4248 - val_mean_squared_error: 5215.3242
# Epoch 622/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14427.8232 - mean_squared_error: 6293.1016 - val_loss: 12114.6074 - val_mean_squared_error: 5437.4111
# Epoch 623/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13804.0137 - mean_squared_error: 5986.0278 - val_loss: 11299.0205 - val_mean_squared_error: 5052.3477
# Epoch 624/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13472.9971 - mean_squared_error: 5834.5444 - val_loss: 12386.8613 - val_mean_squared_error: 5597.1758
# Epoch 625/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14000.7334 - mean_squared_error: 6090.5034 - val_loss: 10820.5840 - val_mean_squared_error: 4824.1611
# Epoch 626/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13081.7764 - mean_squared_error: 5652.2383 - val_loss: 10626.6094 - val_mean_squared_error: 4740.8857
# Epoch 627/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13138.5312 - mean_squared_error: 5705.7876 - val_loss: 12854.1250 - val_mean_squared_error: 5832.1865
# Epoch 628/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14518.0293 - mean_squared_error: 6341.7720 - val_loss: 10922.6416 - val_mean_squared_error: 4888.3022
# Epoch 629/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13916.7520 - mean_squared_error: 6089.2446 - val_loss: 10452.2588 - val_mean_squared_error: 4646.4917
# Epoch 630/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14577.5498 - mean_squared_error: 6444.7939 - val_loss: 14627.2578 - val_mean_squared_error: 6714.9619
# Epoch 631/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 15860.6367 - mean_squared_error: 7037.2144 - val_loss: 12010.6318 - val_mean_squared_error: 5424.1836
# Epoch 632/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13684.6543 - mean_squared_error: 5949.0278 - val_loss: 13443.4004 - val_mean_squared_error: 6143.9902
# Epoch 633/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14334.7285 - mean_squared_error: 6251.3599 - val_loss: 10084.3223 - val_mean_squared_error: 4467.6313
# Epoch 634/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13091.3008 - mean_squared_error: 5655.7124 - val_loss: 10097.2979 - val_mean_squared_error: 4472.8301
# Epoch 635/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13159.0225 - mean_squared_error: 5707.9707 - val_loss: 13874.0947 - val_mean_squared_error: 6359.5381
# Epoch 636/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13783.9053 - mean_squared_error: 6018.4116 - val_loss: 9839.6104 - val_mean_squared_error: 4347.5977
# Epoch 637/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12540.1289 - mean_squared_error: 5399.6416 - val_loss: 9789.4102 - val_mean_squared_error: 4321.4082
# Epoch 638/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12426.8564 - mean_squared_error: 5343.1948 - val_loss: 9884.3145 - val_mean_squared_error: 4373.7725
# Epoch 639/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12414.6572 - mean_squared_error: 5337.5337 - val_loss: 9907.1045 - val_mean_squared_error: 4376.2588
# Epoch 640/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12211.6719 - mean_squared_error: 5241.7593 - val_loss: 10499.6328 - val_mean_squared_error: 4684.1440
# Epoch 641/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12508.0498 - mean_squared_error: 5386.0923 - val_loss: 10336.2002 - val_mean_squared_error: 4592.1211
# Epoch 642/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 12140.3799 - mean_squared_error: 5209.6680 - val_loss: 9792.5332 - val_mean_squared_error: 4325.8057
# Epoch 643/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12028.8105 - mean_squared_error: 5166.3081 - val_loss: 10346.3477 - val_mean_squared_error: 4604.4653
# Epoch 644/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 12189.6680 - mean_squared_error: 5244.6875 - val_loss: 9488.3535 - val_mean_squared_error: 4177.2710
# Epoch 645/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 11895.1514 - mean_squared_error: 5097.3237 - val_loss: 10222.6777 - val_mean_squared_error: 4534.8916
# Epoch 646/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12264.7344 - mean_squared_error: 5284.1733 - val_loss: 10256.7578 - val_mean_squared_error: 4554.4282
# Epoch 647/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12201.4092 - mean_squared_error: 5249.8916 - val_loss: 9703.0049 - val_mean_squared_error: 4271.5918
# Epoch 648/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 11992.3975 - mean_squared_error: 5148.8003 - val_loss: 10383.5371 - val_mean_squared_error: 4621.9502
# Epoch 649/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12475.9570 - mean_squared_error: 5398.4214 - val_loss: 9833.9980 - val_mean_squared_error: 4350.4546
# Epoch 650/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12407.5254 - mean_squared_error: 5336.6812 - val_loss: 10139.9473 - val_mean_squared_error: 4492.1055
# Epoch 651/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12513.5322 - mean_squared_error: 5379.8555 - val_loss: 10516.7490 - val_mean_squared_error: 4685.1978
# Epoch 652/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13129.7656 - mean_squared_error: 5709.4761 - val_loss: 10346.6953 - val_mean_squared_error: 4592.7456
# Epoch 653/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12653.5742 - mean_squared_error: 5454.0649 - val_loss: 10849.4316 - val_mean_squared_error: 4832.7319
# Epoch 654/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12719.9424 - mean_squared_error: 5488.1748 - val_loss: 10944.0781 - val_mean_squared_error: 4897.9683
# Epoch 655/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13393.3740 - mean_squared_error: 5858.8164 - val_loss: 11183.2109 - val_mean_squared_error: 5023.3701
# Epoch 656/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13183.3486 - mean_squared_error: 5744.4189 - val_loss: 11822.3428 - val_mean_squared_error: 5331.9653
# Epoch 657/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13713.4971 - mean_squared_error: 5974.6143 - val_loss: 12088.1631 - val_mean_squared_error: 5474.0469
# Epoch 658/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14917.1396 - mean_squared_error: 6641.1504 - val_loss: 12921.2734 - val_mean_squared_error: 5875.4780
# Epoch 659/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14606.2764 - mean_squared_error: 6467.7705 - val_loss: 14138.5918 - val_mean_squared_error: 6477.3101
# Epoch 660/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14286.7666 - mean_squared_error: 6255.6362 - val_loss: 15336.1064 - val_mean_squared_error: 7087.2808
# Epoch 661/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 15906.0791 - mean_squared_error: 7035.0596 - val_loss: 10181.1914 - val_mean_squared_error: 4511.0029
# Epoch 662/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13531.8740 - mean_squared_error: 5882.3955 - val_loss: 9948.1484 - val_mean_squared_error: 4401.6836
# Epoch 663/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14132.6934 - mean_squared_error: 6232.9653 - val_loss: 15127.3037 - val_mean_squared_error: 6992.8076
# Epoch 664/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 15603.7656 - mean_squared_error: 6945.5605 - val_loss: 12043.7051 - val_mean_squared_error: 5425.8667
# Epoch 665/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13755.8193 - mean_squared_error: 6013.4722 - val_loss: 11106.3135 - val_mean_squared_error: 4952.6182
# Epoch 666/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13638.6885 - mean_squared_error: 5930.0942 - val_loss: 10564.5996 - val_mean_squared_error: 4687.1377
# Epoch 667/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13007.4277 - mean_squared_error: 5620.8638 - val_loss: 10332.1631 - val_mean_squared_error: 4586.5039
# Epoch 668/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12922.7432 - mean_squared_error: 5598.6592 - val_loss: 10171.9287 - val_mean_squared_error: 4512.5771
# Epoch 669/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12976.9600 - mean_squared_error: 5615.2109 - val_loss: 10230.4609 - val_mean_squared_error: 4537.2178
# Epoch 670/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12834.7461 - mean_squared_error: 5546.0342 - val_loss: 11951.4668 - val_mean_squared_error: 5386.9629
# Epoch 671/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13569.2744 - mean_squared_error: 5894.6738 - val_loss: 11947.9561 - val_mean_squared_error: 5385.4658
# Epoch 672/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13480.4717 - mean_squared_error: 5848.3032 - val_loss: 11994.0215 - val_mean_squared_error: 5399.5117
# Epoch 673/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13802.8564 - mean_squared_error: 5997.9487 - val_loss: 12420.4863 - val_mean_squared_error: 5605.3398
# Epoch 674/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14452.5635 - mean_squared_error: 6316.4922 - val_loss: 11274.5146 - val_mean_squared_error: 5049.7690
# Epoch 675/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14291.3398 - mean_squared_error: 6274.1353 - val_loss: 11021.4639 - val_mean_squared_error: 4929.9004
# Epoch 676/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13770.4854 - mean_squared_error: 6013.9951 - val_loss: 11400.6826 - val_mean_squared_error: 5111.5171
# Epoch 677/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13481.2344 - mean_squared_error: 5852.4463 - val_loss: 10901.8525 - val_mean_squared_error: 4878.9873
# Epoch 678/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12998.9473 - mean_squared_error: 5632.5356 - val_loss: 11405.7773 - val_mean_squared_error: 5130.0098
# Epoch 679/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12733.4229 - mean_squared_error: 5512.1914 - val_loss: 10106.2832 - val_mean_squared_error: 4487.6274
# Epoch 680/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12401.9697 - mean_squared_error: 5351.1626 - val_loss: 10378.1377 - val_mean_squared_error: 4615.7158
# Epoch 681/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12448.0117 - mean_squared_error: 5371.0410 - val_loss: 10324.6611 - val_mean_squared_error: 4600.3682
# Epoch 682/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12160.6738 - mean_squared_error: 5236.2256 - val_loss: 10841.2539 - val_mean_squared_error: 4849.2935
# Epoch 683/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12440.8027 - mean_squared_error: 5381.6216 - val_loss: 10580.8457 - val_mean_squared_error: 4723.5371
# Epoch 684/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12391.1318 - mean_squared_error: 5351.7764 - val_loss: 11044.3076 - val_mean_squared_error: 4941.6631
# Epoch 685/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12581.3467 - mean_squared_error: 5434.5996 - val_loss: 11344.6934 - val_mean_squared_error: 5092.3857
# Epoch 686/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12534.3457 - mean_squared_error: 5418.3740 - val_loss: 11557.0176 - val_mean_squared_error: 5197.2012
# Epoch 687/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12764.3105 - mean_squared_error: 5530.6060 - val_loss: 11026.8164 - val_mean_squared_error: 4937.6733
# Epoch 688/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 12686.3525 - mean_squared_error: 5503.8013 - val_loss: 11452.4883 - val_mean_squared_error: 5156.0732
# Epoch 689/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12806.2451 - mean_squared_error: 5544.2773 - val_loss: 12596.6357 - val_mean_squared_error: 5716.5938
# Epoch 690/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14020.6660 - mean_squared_error: 6107.0068 - val_loss: 11746.9043 - val_mean_squared_error: 5305.0029
# Epoch 691/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13418.6348 - mean_squared_error: 5858.4551 - val_loss: 11006.9482 - val_mean_squared_error: 4916.0615
# Epoch 692/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13329.3623 - mean_squared_error: 5836.9146 - val_loss: 12461.4385 - val_mean_squared_error: 5648.7393
# Epoch 693/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 14096.2539 - mean_squared_error: 6156.7168 - val_loss: 10759.1543 - val_mean_squared_error: 4791.7256
# Epoch 694/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13567.7959 - mean_squared_error: 5926.2671 - val_loss: 10597.1572 - val_mean_squared_error: 4727.5098

# %% [markdown]
# ##  Save trained model

# %%
model.save('Chikusei_2x__saved_model.keras')

# %% [markdown]
# ## Report the six types of results in terms of PSNR, SSIM, SAM, Correlation Coefficient, ERGAS, and RMSE.

# %%
def psnr(y_true, y_pred, max_pixel=None):
    """
    Compute PSNR for each spectral band separately and return the average.
    
    Args:
        y_true: Ground truth image, shape (H, W, B)
        y_pred: Super-resolved image, shape (H, W, B)
        max_pixel: Maximum pixel value (None = use actual max from y_true)
    
    Returns:
        Average PSNR across all bands
    """
    if max_pixel is None:
        max_pixel = np.max(y_true)  # Auto-detect max value if not provided

    B = y_true.shape[-1]  # Number of spectral bands
    psnr_values = []
    
    for i in range(B):  # Loop over bands
        mse = np.mean((y_true[..., i] - y_pred[..., i]) ** 2)
        if mse == 0:
            psnr_values.append(float('inf'))  # Perfect reconstruction
        else:
            psnr = 20 * np.log10(max_pixel / np.sqrt(mse))
            psnr_values.append(psnr)
    
    return np.mean(psnr_values)  # Average across bands

# Function to calculate SSIM with channel_axis
def ssim_value(y_true, y_pred):
    if y_true.shape != y_pred.shape:
        raise ValueError(f"Shape mismatch: y_true shape {y_true.shape} vs y_pred shape {y_pred.shape}")
    
    data_range = y_true.max() - y_true.min()  # Calculate data range from y_true
    ssim_val = ssim(y_true, y_pred, data_range=data_range, channel_axis=-1)
    return ssim_val

# Function to calculate Correlation Coefficient
def correlation_coefficient(y_true, y_pred):
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()
    corr_matrix = np.corrcoef(y_true_flat, y_pred_flat)
    corr_value = corr_matrix[0, 1]
    return corr_value

# Function to calculate Spectral Angle Mapper (SAM) in degrees
def sam(y_true, y_pred):
    y_true_reshaped = y_true.reshape(-1, y_true.shape[-1])
    y_pred_reshaped = y_pred.reshape(-1, y_pred.shape[-1])
    
    non_zero_mask = (np.linalg.norm(y_true_reshaped, axis=1) > 1e-10) & (np.linalg.norm(y_pred_reshaped, axis=1) > 1e-10)
    dot_product = np.sum(y_true_reshaped[non_zero_mask] * y_pred_reshaped[non_zero_mask], axis=1)
    norm_true = np.linalg.norm(y_true_reshaped[non_zero_mask], axis=1)
    norm_pred = np.linalg.norm(y_pred_reshaped[non_zero_mask], axis=1)
    
    with np.errstate(divide='ignore', invalid='ignore'):
        angles = np.arccos(np.clip(dot_product / (norm_true * norm_pred), -1.0, 1.0))
    
    if angles.size > 0:
        sam_value_degrees = np.mean(angles) * (180 / np.pi)
    else:
        sam_value_degrees = 0
    
    return sam_value_degrees

# Function to normalize the images
def normalize(image):
    min_val = np.min(image)
    max_val = np.max(image)
    return (image - min_val) / (max_val - min_val)  # Normalize to [0, 1]

# Function to calculate Root Mean Squared Error (RMSE) for hyperspectral images (normalized)
def rmse_bandwise(y_true, y_pred):
    if y_true.shape != y_pred.shape:
        raise ValueError("Shape mismatch between true and predicted images.")
    
    bands = y_true.shape[-1]
    rmse_per_band = []

    for b in range(bands):
        band_true = y_true[:, :, b]
        band_pred = y_pred[:, :, b]
        
        mse_band = np.mean((band_true - band_pred) ** 2)
        rmse_band_value = np.sqrt(mse_band)
        rmse_per_band.append(rmse_band_value)

    # Normalize RMSE by the maximum value in y_true across all bands
    max_value = np.max(y_true)
    normalized_rmse = np.mean(rmse_per_band) / max_value
    return normalized_rmse


# Assuming hybrid_sr_model is trained, and X_test_lr, X_test_hr are defined
predicted_hr_images =  model.predict(X_test_lr)

# Validate shapes match for test and predictions
if predicted_hr_images.shape != X_test_hr.shape:
    raise ValueError(f"Shape mismatch: predicted_hr_images shape {predicted_hr_images.shape} vs X_test_hr shape {X_test_hr.shape}")

# Calculate metrics per test sample
psnr_values, ssim_values, cc_values, sam_values, ergas_values, rmse_values = [], [], [], [], [], []

for i in range(len(X_test_hr)):
    psnr_values.append(psnr(X_test_hr[i], predicted_hr_images[i]))
    ssim_values.append(ssim_value(X_test_hr[i], predicted_hr_images[i]))
    cc_values.append(correlation_coefficient(X_test_hr[i], predicted_hr_images[i]))
    sam_values.append(sam(X_test_hr[i], predicted_hr_images[i]))
    rmse_values.append(rmse_bandwise(X_test_hr[i], predicted_hr_images[i]))

# Average metrics
average_psnr = np.mean(psnr_values)
average_ssim = np.mean(ssim_values)
average_cc = np.mean(cc_values)
average_sam = np.mean(sam_values)
average_ergas = np.mean(ergas_values)
average_rmse = np.mean(rmse_values)

# Print the evaluation metrics
print("Average PSNR on the test set:", average_psnr)
print("Average SSIM on the test set:", average_ssim)
print("Average SAM on the test set (in degrees):", average_sam)
print("Average Correlation Coefficient on the test set:", average_cc)
print("Average RMSE:", average_rmse)  # Indicate RMSE is normalizedex
# Out:
# 2025-08-01 11:25:59.519109: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# Average PSNR on the test set: 38.57893089336064
# Average SSIM on the test set: 0.9564838385560435
# Average SAM on the test set (in degrees): 1.4337278601351966
# Average Correlation Coefficient on the test set: 0.9980572007150088
# Average RMSE: 0.013496014613011118
# /usr/local/lib64/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib64/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Download the dataset from the following link before using this notebook (Chikusei Centre scene):

# %% [markdown]
# ##  https://www.kaggle.com/datasets/mingliu123/chikusei

# %% [markdown]
# ## Import required libraries

# %%
import numpy as np
import h5py
import random
from scipy.io import loadmat
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, UpSampling2D, Add, Activation, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.losses import MeanSquaredError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping
from skimage.metrics import structural_similarity as ssim
# GPU setup
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("✅ GPU available. Using:", gpus[0])
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
else:
    print("❌ GPU not available. Running on CPU.")
# Out:
# 2025-08-01 11:28:46.244365: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-01 11:28:46.272014: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754036926.288362 2079614 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754036926.293483 2079614 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-01 11:28:46.311201: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✅ GPU available. Using: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# ##  Reproducibility Setup ( Set a consistent random seed for NumPy, TensorFlow, and Python's random module to ensure the same results on each run)

# %%
seed_value = 42
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)
os.environ['PYTHONHASHSEED'] = str(seed_value)

tf.config.experimental.enable_op_determinism()
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

# %% [markdown]
# ##  Load the Chikusei Dataset

# %%
# -----------------------------
# Load Chikusei dataset
# -----------------------------
with h5py.File("Chikusei.mat", "r") as f:
    raw_data = f['chikusei'][:]

# Transpose to (H, W, B)
if raw_data.shape[0] <= 300:
    hyperspectral_image = raw_data.transpose(1, 2, 0)
else:
    hyperspectral_image = raw_data

print("Original image shape:", hyperspectral_image.shape)
# Out:
# Original image shape: (2335, 2517, 128)

# %% [markdown]
# ##  Parameter Initialization for dataset preprocessing only

# %%
# -----------------------------
# Parameters
# -----------------------------
crop_height = 512
crop_width = 512
crop_bands = 128

test_patch_size = (128, 128)
train_patch_size = (128, 128)
downscale_factor = 4
nodata_value = 15000
overlap = 32
validation_ratio = 0.1

# %% [markdown]
# ## Crop center region for training and testing

# %%
# -----------------------------
# Crop center region
# -----------------------------
H, W, B = hyperspectral_image.shape
start_i = (H - crop_height) // 2
start_j = (W - crop_width) // 2

cropped_image = hyperspectral_image[start_i:start_i + crop_height,
                                    start_j:start_j + crop_width,
                                    :crop_bands]

print("Cropped subimage shape:", cropped_image.shape)
# Out:
# Cropped subimage shape: (512, 512, 128)

# %% [markdown]
# ## Extract test set

# %%
# -----------------------------
# Extract test set: 2 non-overlapping patches from top rows
# -----------------------------
test_hr_list, test_lr_list = [], []
patch_h, patch_w = test_patch_size

for j in range(0, 2 * patch_w, patch_w):
    if j + patch_w > crop_width:
        continue

    patch = cropped_image[0:patch_h, j:j + patch_w, :]
    if patch.shape[:2] != test_patch_size or np.any(patch >= nodata_value):
        continue

    patch_tf = tf.convert_to_tensor(patch[np.newaxis, ...], dtype=tf.float32)
    patch_lr_tf = tf.image.resize(
        patch_tf,
        [patch_h // downscale_factor, patch_w // downscale_factor],
        method='area'
    )
    patch_lr = patch_lr_tf[0].numpy()

    test_hr_list.append(patch)
    test_lr_list.append(patch_lr)

X_test_hr = np.stack(test_hr_list)
X_test_lr = np.stack(test_lr_list)
# Out:
# I0000 00:00:1754036971.592029 2079614 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31141 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:61:00.0, compute capability: 7.0

# %% [markdown]
# ## Extract Training Patches

# %%
# -----------------------------
# Extract training/validation from remaining region
# -----------------------------
train_hr, train_lr = [], []
stride = train_patch_size[0] - overlap
train_h, train_w = train_patch_size

for i in range(patch_h, crop_height - train_h + 1, stride):
    for j in range(0, crop_width - train_w + 1, stride):
        patch = cropped_image[i:i + train_h, j:j + train_w, :]

        if patch.shape[:2] != train_patch_size or np.any(patch >= nodata_value):
            continue

        patch_tf = tf.convert_to_tensor(patch[np.newaxis, ...], dtype=tf.float32)
        patch_lr_tf = tf.image.resize(
            patch_tf,
            [train_h // downscale_factor, train_w // downscale_factor],
            method='area'
        )
        patch_lr = patch_lr_tf[0].numpy()

        train_hr.append(patch)
        train_lr.append(patch_lr)

train_hr = np.array(train_hr)
train_lr = np.array(train_lr)

# %% [markdown]
# ## Validation Split FOR train and validation

# %%
# -----------------------------
# Split 10% into validation set
# -----------------------------
indices = np.arange(train_hr.shape[0])
np.random.shuffle(indices)

val_count = max(1, int(validation_ratio * len(indices)))
X_validation_hr = train_hr[indices[:val_count]]
X_validation_lr = train_lr[indices[:val_count]]
X_train_hr = train_hr[indices[val_count:]]
X_train_lr = train_lr[indices[val_count:]]

# -----------------------------
# Print dataset shapes
# -----------------------------
print("\n✅ Dataset summary:")
print("X_test_hr:", X_test_hr.shape)
print("X_test_lr:", X_test_lr.shape)
print("X_train_hr:", X_train_hr.shape)
print("X_train_lr:", X_train_lr.shape)
print("X_validation_hr:", X_validation_hr.shape)
print("X_validation_lr:", X_validation_lr.shape)
print(f"Validation samples: {val_count} / {len(indices)}")
# Out:
# ✅ Dataset summary:
# X_test_hr: (2, 128, 128, 128)
# X_test_lr: (2, 32, 32, 128)
# X_train_hr: (14, 128, 128, 128)
# X_train_lr: (14, 32, 32, 128)
# X_validation_hr: (1, 128, 128, 128)
# X_validation_lr: (1, 32, 32, 128)
# Validation samples: 1 / 15

# %% [markdown]
# ##  Model development

# %%
# -----------------------------
# Custom Loss Function: Spatial + Spectral Gradient + MSE
# -----------------------------
def spatial_spectral_gradient_loss(weight_mse=1.0, weight_spatial=0.1, weight_spectral=0.1):
    def loss_fn(y_true, y_pred):
        mse_loss = K.mean(K.square(y_true - y_pred))

        grad_true_x = y_true[:, 1:, :, :] - y_true[:, :-1, :, :]
        grad_pred_x = y_pred[:, 1:, :, :] - y_pred[:, :-1, :, :]
        grad_true_y = y_true[:, :, 1:, :] - y_true[:, :, :-1, :]
        grad_pred_y = y_pred[:, :, 1:, :] - y_pred[:, :, :-1, :]
        spatial_loss = K.mean(K.square(grad_true_x - grad_pred_x)) + K.mean(K.square(grad_true_y - grad_pred_y))

        grad_true_s = y_true[:, :, :, 1:] - y_true[:, :, :, :-1]
        grad_pred_s = y_pred[:, :, :, 1:] - y_pred[:, :, :, :-1]
        spectral_loss = K.mean(K.square(grad_true_s - grad_pred_s))

        return weight_mse * mse_loss + weight_spatial * spatial_loss + weight_spectral * spectral_loss

    return loss_fn

# -----------------------------
# Residual Block
# -----------------------------
def resnet_block(x, filters):
    shortcut = x
    x = Conv2D(filters, 3, padding='same', activation='relu')(x)
    x = Conv2D(filters, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# -----------------------------
# Spectral Unmixing Block
# -----------------------------
def spectral_unmixing_block(x, filters):
    x = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)
    x = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)
    return x

# -----------------------------
# Spectral–Spatial Fusion Block
# -----------------------------
def spectral_spatial_fusion_block(x, filters):
    spatial = Conv2D(filters, kernel_size=3, padding='same', activation='relu')(x)
    spectral = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)
    fused = Concatenate()([spatial, spectral])
    fused = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(fused)
    return fused

# -----------------------------
# Model Architecture (Fully Convolutional)
# -----------------------------
def build_simple_sr_model(input_shape=(None, None, 128)):
    inputs = Input(shape=input_shape)

    # Pre-Upsampling
    x = UpSampling2D(size=(4, 4), interpolation='bilinear')(inputs)

    x = spectral_unmixing_block(x, filters=64)
    x = spectral_spatial_fusion_block(x, filters=64)
    x = Conv2D(64, 3, padding='same', activation='relu')(x)

    for _ in range(3):
        x = resnet_block(x, 64)

    output = Conv2D(input_shape[-1], 3, padding='same', activation='linear')(x)

    return Model(inputs, output, name='SR_Model_PreUpsampling')

# -----------------------------
# Build and Compile Model
# -----------------------------
model = build_simple_sr_model(input_shape=(None, None, 128))

model.compile(
    optimizer='adam',
    loss=spatial_spectral_gradient_loss(
        weight_mse=2.0,
        weight_spatial=0.1,
        weight_spectral=0.1
    ),
    metrics=[MeanSquaredError()]
)

# -----------------------------
# Parameter Count
# -----------------------------
total_params = model.count_params()
size_in_bytes = total_params * 4
size_in_mb = size_in_bytes / (1024 ** 2)

print(f"📢 Model size: {size_in_mb:.2f} MB")
print(f"📊 Total Parameters: {total_params / 1e6:.2f} Million")
# Out:
# 📢 Model size: 1.51 MB
# 📊 Total Parameters: 0.39 Million

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Train the model and get the training history with early stopping
history = model.fit(
    X_train_lr, 
    X_train_hr, 
    epochs=1500, 
    batch_size=4, 
    validation_data=(X_validation_lr, X_validation_hr),
    callbacks=[early_stopping]  # Add the early stopping callback here
)

# Visualize training and validation loss over epochs
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)  # Add grid for better readability
plt.show()
# Out:
# Epoch 1/1500
# 2025-08-01 11:29:33.379131: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754036976.338205 2080636 service.cc:148] XLA service 0x7fb460421770 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754036976.338228 2080636 service.cc:156]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2025-08-01 11:29:36.417098: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1754036976.797284 2080636 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4904520.5000 - mean_squared_error: 2443024.0000
# 2025-08-01 11:29:38.919493: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion', 128 bytes spill stores, 120 bytes spill loads
#
# I0000 00:00:1754036978.938282 2080636 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - loss: 4723613.5000 - mean_squared_error: 2326393.2500
# 2025-08-01 11:29:41.305796: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4615069.5000 - mean_squared_error: 2256415.0000 - val_loss: 1947219.1250 - val_mean_squared_error: 919462.6250
# Epoch 2/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1604410.2500 - mean_squared_error: 740822.3125 - val_loss: 468012.4688 - val_mean_squared_error: 224329.0156
# Epoch 3/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 559553.7500 - mean_squared_error: 265905.1250 - val_loss: 426077.5938 - val_mean_squared_error: 203288.6406
# Epoch 4/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 479517.6875 - mean_squared_error: 225973.8281 - val_loss: 305588.3438 - val_mean_squared_error: 144990.0312
# Epoch 5/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 363484.7500 - mean_squared_error: 170645.6562 - val_loss: 204590.2969 - val_mean_squared_error: 97473.5938
# Epoch 6/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 261199.3281 - mean_squared_error: 122729.6797 - val_loss: 157045.7188 - val_mean_squared_error: 74227.2812
# Epoch 7/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 222221.8438 - mean_squared_error: 103989.5703 - val_loss: 140700.2500 - val_mean_squared_error: 66760.6875
# Epoch 8/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 200078.1094 - mean_squared_error: 93794.9062 - val_loss: 122476.8203 - val_mean_squared_error: 58172.0391
# Epoch 9/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 181683.2812 - mean_squared_error: 85183.7031 - val_loss: 116817.3828 - val_mean_squared_error: 55395.0312
# Epoch 10/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 173059.2344 - mean_squared_error: 81015.2031 - val_loss: 105794.7969 - val_mean_squared_error: 50050.7656
# Epoch 11/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 165460.5938 - mean_squared_error: 77431.9375 - val_loss: 100682.3672 - val_mean_squared_error: 47592.8633
# Epoch 12/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 159113.3281 - mean_squared_error: 74354.3984 - val_loss: 92974.5000 - val_mean_squared_error: 43871.6953
# Epoch 13/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 155620.8594 - mean_squared_error: 72654.4141 - val_loss: 91243.0859 - val_mean_squared_error: 43088.8438
# Epoch 14/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 152284.2812 - mean_squared_error: 71045.3750 - val_loss: 90288.1875 - val_mean_squared_error: 42653.8398
# Epoch 15/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 149123.1094 - mean_squared_error: 69464.4922 - val_loss: 96493.9453 - val_mean_squared_error: 45768.8359
# Epoch 16/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 145216.3281 - mean_squared_error: 67798.1172 - val_loss: 82858.6016 - val_mean_squared_error: 39070.6328
# Epoch 17/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 143576.7031 - mean_squared_error: 67045.7578 - val_loss: 78790.3203 - val_mean_squared_error: 37070.9688
# Epoch 18/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 143413.2500 - mean_squared_error: 66812.2891 - val_loss: 81181.1250 - val_mean_squared_error: 38286.6523
# Epoch 19/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 135205.7500 - mean_squared_error: 62821.4609 - val_loss: 82392.1875 - val_mean_squared_error: 38938.7617
# Epoch 20/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 131491.0312 - mean_squared_error: 61099.3086 - val_loss: 74889.0078 - val_mean_squared_error: 35252.5938
# Epoch 21/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 128695.5859 - mean_squared_error: 59777.3633 - val_loss: 74567.3281 - val_mean_squared_error: 35153.5469
# Epoch 22/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 133269.7656 - mean_squared_error: 61984.9219 - val_loss: 73207.7734 - val_mean_squared_error: 34505.0000
# Epoch 23/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 125228.8828 - mean_squared_error: 58187.6562 - val_loss: 68721.8047 - val_mean_squared_error: 32324.3809
# Epoch 24/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 122504.4531 - mean_squared_error: 56831.9180 - val_loss: 66543.2734 - val_mean_squared_error: 31275.7246
# Epoch 25/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 122538.6328 - mean_squared_error: 56879.3555 - val_loss: 65851.6562 - val_mean_squared_error: 30961.9766
# Epoch 26/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 118901.2734 - mean_squared_error: 55157.3359 - val_loss: 64215.4375 - val_mean_squared_error: 30181.5430
# Epoch 27/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 117522.1016 - mean_squared_error: 54473.6484 - val_loss: 62382.8047 - val_mean_squared_error: 29285.9863
# Epoch 28/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 115545.3359 - mean_squared_error: 53606.6055 - val_loss: 63653.3320 - val_mean_squared_error: 29939.9141
# Epoch 29/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 114946.8359 - mean_squared_error: 53251.4961 - val_loss: 60631.8633 - val_mean_squared_error: 28444.0391
# Epoch 30/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 113571.1562 - mean_squared_error: 52678.7148 - val_loss: 62842.6133 - val_mean_squared_error: 29550.0234
# Epoch 31/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 112586.1797 - mean_squared_error: 52121.2852 - val_loss: 60096.8594 - val_mean_squared_error: 28189.0059
# Epoch 32/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 114067.5938 - mean_squared_error: 52901.4844 - val_loss: 60358.9727 - val_mean_squared_error: 28319.5117
# Epoch 33/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 113586.7344 - mean_squared_error: 52578.0859 - val_loss: 65059.1836 - val_mean_squared_error: 30679.3945
# Epoch 34/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 118315.3438 - mean_squared_error: 54849.9609 - val_loss: 69023.9531 - val_mean_squared_error: 32654.0547
# Epoch 35/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 118370.3281 - mean_squared_error: 55106.3516 - val_loss: 60050.5234 - val_mean_squared_error: 28178.0547
# Epoch 36/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 110560.6406 - mean_squared_error: 51133.4336 - val_loss: 63815.3320 - val_mean_squared_error: 30053.9102
# Epoch 37/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 111342.3125 - mean_squared_error: 51558.2383 - val_loss: 58339.4648 - val_mean_squared_error: 27331.2812
# Epoch 38/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 108203.6250 - mean_squared_error: 49998.8047 - val_loss: 56953.3203 - val_mean_squared_error: 26644.5391
# Epoch 39/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 106168.2656 - mean_squared_error: 49030.7109 - val_loss: 56765.0938 - val_mean_squared_error: 26554.3984
# Epoch 40/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 105610.4922 - mean_squared_error: 48773.6016 - val_loss: 57317.0469 - val_mean_squared_error: 26831.6777
# Epoch 41/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 105382.8203 - mean_squared_error: 48648.2656 - val_loss: 57121.6406 - val_mean_squared_error: 26736.1133
# Epoch 42/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 104971.4531 - mean_squared_error: 48444.7773 - val_loss: 56005.0273 - val_mean_squared_error: 26181.2383
# Epoch 43/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 104053.9844 - mean_squared_error: 48003.5234 - val_loss: 56290.5625 - val_mean_squared_error: 26327.9336
# Epoch 44/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 103788.7031 - mean_squared_error: 47870.2852 - val_loss: 56296.7891 - val_mean_squared_error: 26332.8535
# Epoch 45/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 103430.3750 - mean_squared_error: 47692.8633 - val_loss: 55616.0898 - val_mean_squared_error: 25992.7969
# Epoch 46/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 103023.9141 - mean_squared_error: 47504.8828 - val_loss: 56140.6992 - val_mean_squared_error: 26258.1035
# Epoch 47/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 102996.4141 - mean_squared_error: 47486.8750 - val_loss: 55016.8203 - val_mean_squared_error: 25700.4375
# Epoch 48/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 102284.4766 - mean_squared_error: 47146.8867 - val_loss: 55231.6094 - val_mean_squared_error: 25810.7812
# Epoch 49/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 102048.9375 - mean_squared_error: 47030.0820 - val_loss: 54335.4141 - val_mean_squared_error: 25365.2344
# Epoch 50/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 101495.0234 - mean_squared_error: 46759.0898 - val_loss: 54760.5586 - val_mean_squared_error: 25579.7168
# Epoch 51/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 101919.3750 - mean_squared_error: 46981.6445 - val_loss: 54272.6133 - val_mean_squared_error: 25338.0273
# Epoch 52/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 101671.7188 - mean_squared_error: 46854.4609 - val_loss: 54492.1523 - val_mean_squared_error: 25449.9961
# Epoch 53/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 102883.7891 - mean_squared_error: 47446.1211 - val_loss: 54670.1211 - val_mean_squared_error: 25538.5703
# Epoch 54/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 104240.8750 - mean_squared_error: 48074.8203 - val_loss: 59050.2031 - val_mean_squared_error: 27730.4473
# Epoch 55/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 107472.0781 - mean_squared_error: 49627.5898 - val_loss: 63895.8516 - val_mean_squared_error: 30148.7969
# Epoch 56/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 112263.0469 - mean_squared_error: 52189.7148 - val_loss: 67861.0859 - val_mean_squared_error: 32133.8164
# Epoch 57/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 108175.4688 - mean_squared_error: 50062.5000 - val_loss: 56687.0938 - val_mean_squared_error: 26548.9668
# Epoch 58/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 104065.2422 - mean_squared_error: 48015.3945 - val_loss: 56585.1289 - val_mean_squared_error: 26496.9180
# Epoch 59/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 102538.5703 - mean_squared_error: 47289.8555 - val_loss: 54700.7656 - val_mean_squared_error: 25556.6543
# Epoch 60/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 101818.2578 - mean_squared_error: 46993.2148 - val_loss: 54771.3477 - val_mean_squared_error: 25599.6523
# Epoch 61/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 100368.3984 - mean_squared_error: 46223.6836 - val_loss: 54568.2539 - val_mean_squared_error: 25497.8711
# Epoch 62/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 99821.2656 - mean_squared_error: 45972.8203 - val_loss: 53334.2656 - val_mean_squared_error: 24884.6543
# Epoch 63/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 99157.8828 - mean_squared_error: 45645.7461 - val_loss: 52827.5469 - val_mean_squared_error: 24633.9023
# Epoch 64/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 98877.7266 - mean_squared_error: 45520.0586 - val_loss: 53161.1328 - val_mean_squared_error: 24802.2207
# Epoch 65/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 98278.7188 - mean_squared_error: 45220.1641 - val_loss: 52788.3203 - val_mean_squared_error: 24618.1172
# Epoch 66/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 97981.5312 - mean_squared_error: 45081.5508 - val_loss: 52778.5742 - val_mean_squared_error: 24615.5781
# Epoch 67/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 98303.6172 - mean_squared_error: 45256.1055 - val_loss: 52696.5664 - val_mean_squared_error: 24577.1074
# Epoch 68/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 97716.7734 - mean_squared_error: 44956.5273 - val_loss: 52615.5781 - val_mean_squared_error: 24537.1289
# Epoch 69/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 97390.8750 - mean_squared_error: 44799.8711 - val_loss: 52390.8750 - val_mean_squared_error: 24426.4961
# Epoch 70/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 97418.2812 - mean_squared_error: 44824.0820 - val_loss: 52959.9336 - val_mean_squared_error: 24713.0293
# Epoch 71/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 97646.0781 - mean_squared_error: 44940.9141 - val_loss: 52260.8867 - val_mean_squared_error: 24366.1738
# Epoch 72/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 97021.4688 - mean_squared_error: 44627.6641 - val_loss: 52354.5273 - val_mean_squared_error: 24412.6914
# Epoch 73/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 96855.0703 - mean_squared_error: 44552.6875 - val_loss: 53026.8359 - val_mean_squared_error: 24750.5801
# Epoch 74/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 97197.0469 - mean_squared_error: 44721.7891 - val_loss: 52969.8242 - val_mean_squared_error: 24724.1387
# Epoch 75/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 97441.1172 - mean_squared_error: 44854.9805 - val_loss: 53335.6758 - val_mean_squared_error: 24907.6953
# Epoch 76/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 97337.7344 - mean_squared_error: 44794.0625 - val_loss: 54156.6758 - val_mean_squared_error: 25318.4570
# Epoch 77/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 97765.9531 - mean_squared_error: 44994.5312 - val_loss: 55593.8281 - val_mean_squared_error: 26037.1133
# Epoch 78/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 98979.4141 - mean_squared_error: 45567.9297 - val_loss: 57852.4727 - val_mean_squared_error: 27165.7266
# Epoch 79/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 99944.6016 - mean_squared_error: 46024.6055 - val_loss: 59048.0820 - val_mean_squared_error: 27762.5430
# Epoch 80/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 99996.5234 - mean_squared_error: 46095.4492 - val_loss: 54402.3594 - val_mean_squared_error: 25444.4062
# Epoch 81/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 98827.0859 - mean_squared_error: 45584.2305 - val_loss: 52440.6875 - val_mean_squared_error: 24467.7109
# Epoch 82/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 97282.0234 - mean_squared_error: 44781.0195 - val_loss: 53475.3047 - val_mean_squared_error: 24980.8750
# Epoch 83/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 97429.5859 - mean_squared_error: 44819.5391 - val_loss: 52728.8516 - val_mean_squared_error: 24612.1855
# Epoch 84/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 96451.1797 - mean_squared_error: 44364.5430 - val_loss: 53072.4062 - val_mean_squared_error: 24785.5156
# Epoch 85/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 96625.0312 - mean_squared_error: 44436.7773 - val_loss: 55210.6992 - val_mean_squared_error: 25852.7148
# Epoch 86/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 97378.5859 - mean_squared_error: 44816.5625 - val_loss: 54062.0781 - val_mean_squared_error: 25281.6328
# Epoch 87/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 97347.2891 - mean_squared_error: 44770.6250 - val_loss: 55302.6289 - val_mean_squared_error: 25899.6680
# Epoch 88/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 97488.9375 - mean_squared_error: 44861.7109 - val_loss: 53966.3750 - val_mean_squared_error: 25235.8770
# Epoch 89/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 96852.6172 - mean_squared_error: 44569.7109 - val_loss: 53258.5117 - val_mean_squared_error: 24887.8555
# Epoch 90/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 96561.0469 - mean_squared_error: 44445.8789 - val_loss: 51554.7070 - val_mean_squared_error: 24037.9043
# Epoch 91/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 95810.9922 - mean_squared_error: 44089.3984 - val_loss: 51397.6367 - val_mean_squared_error: 23958.7109
# Epoch 92/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 95276.6094 - mean_squared_error: 43820.4766 - val_loss: 51344.5352 - val_mean_squared_error: 23937.5352
# Epoch 93/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 95090.8828 - mean_squared_error: 43712.8203 - val_loss: 51141.5508 - val_mean_squared_error: 23833.6562
# Epoch 94/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 95380.4609 - mean_squared_error: 43844.0039 - val_loss: 50594.8164 - val_mean_squared_error: 23565.6660
# Epoch 95/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 94584.9453 - mean_squared_error: 43474.8086 - val_loss: 50862.3516 - val_mean_squared_error: 23696.2559
# Epoch 96/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 94105.8047 - mean_squared_error: 43259.5977 - val_loss: 50475.1211 - val_mean_squared_error: 23505.4336
# Epoch 97/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 94085.5703 - mean_squared_error: 43245.0195 - val_loss: 50396.9180 - val_mean_squared_error: 23468.4883
# Epoch 98/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 93712.6953 - mean_squared_error: 43045.0352 - val_loss: 50632.2109 - val_mean_squared_error: 23587.4531
# Epoch 99/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 94049.7266 - mean_squared_error: 43206.9453 - val_loss: 50348.7148 - val_mean_squared_error: 23444.4609
# Epoch 100/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 94349.9688 - mean_squared_error: 43366.1094 - val_loss: 50809.5859 - val_mean_squared_error: 23677.1973
# Epoch 101/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 95559.4062 - mean_squared_error: 43969.7695 - val_loss: 50528.4922 - val_mean_squared_error: 23538.4805
# Epoch 102/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 95232.1797 - mean_squared_error: 43818.0859 - val_loss: 50929.4609 - val_mean_squared_error: 23732.4297
# Epoch 103/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 96449.9453 - mean_squared_error: 44374.6914 - val_loss: 52175.1016 - val_mean_squared_error: 24360.6523
# Epoch 104/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 98782.1719 - mean_squared_error: 45482.6016 - val_loss: 56430.7773 - val_mean_squared_error: 26486.4102
# Epoch 105/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 101426.1406 - mean_squared_error: 46759.7227 - val_loss: 65073.0039 - val_mean_squared_error: 30791.3828
# Epoch 106/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 110025.7969 - mean_squared_error: 51149.1523 - val_loss: 73152.0000 - val_mean_squared_error: 34829.3516
# Epoch 107/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 107789.8672 - mean_squared_error: 50024.4219 - val_loss: 53864.1523 - val_mean_squared_error: 25193.8203
# Epoch 108/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 101775.2969 - mean_squared_error: 46922.6758 - val_loss: 61577.7070 - val_mean_squared_error: 29038.9883
# Epoch 109/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 101075.5156 - mean_squared_error: 46666.7969 - val_loss: 50915.2539 - val_mean_squared_error: 23727.4961
# Epoch 110/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 95402.2969 - mean_squared_error: 43869.8125 - val_loss: 53338.9961 - val_mean_squared_error: 24937.1328
# Epoch 111/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 95294.9297 - mean_squared_error: 43812.4648 - val_loss: 52842.6445 - val_mean_squared_error: 24693.3301
# Epoch 112/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 94801.8828 - mean_squared_error: 43587.5039 - val_loss: 50071.4141 - val_mean_squared_error: 23318.1406
# Epoch 113/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 93495.9453 - mean_squared_error: 42957.0508 - val_loss: 49363.8828 - val_mean_squared_error: 22969.9766
# Epoch 114/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 92870.5000 - mean_squared_error: 42646.5391 - val_loss: 49513.3633 - val_mean_squared_error: 23042.9395
# Epoch 115/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 92493.5469 - mean_squared_error: 42465.7734 - val_loss: 49373.9141 - val_mean_squared_error: 22976.0000
# Epoch 116/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 92241.2500 - mean_squared_error: 42343.1602 - val_loss: 49076.6602 - val_mean_squared_error: 22832.0469
# Epoch 117/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 91910.7031 - mean_squared_error: 42183.9375 - val_loss: 49036.7148 - val_mean_squared_error: 22813.6621
# Epoch 118/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 91743.7656 - mean_squared_error: 42107.4297 - val_loss: 49493.4805 - val_mean_squared_error: 23037.8984
# Epoch 119/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 91708.8047 - mean_squared_error: 42089.7148 - val_loss: 48884.5781 - val_mean_squared_error: 22739.9570
# Epoch 120/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 91548.8281 - mean_squared_error: 42013.9414 - val_loss: 49283.1758 - val_mean_squared_error: 22934.9316
# Epoch 121/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 91468.5703 - mean_squared_error: 41982.7070 - val_loss: 49090.6055 - val_mean_squared_error: 22842.1680
# Epoch 122/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 91405.4219 - mean_squared_error: 41950.2500 - val_loss: 48914.6445 - val_mean_squared_error: 22756.5039
# Epoch 123/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 91180.1406 - mean_squared_error: 41842.5469 - val_loss: 48729.3711 - val_mean_squared_error: 22663.9258
# Epoch 124/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 91010.9453 - mean_squared_error: 41764.0625 - val_loss: 48732.1680 - val_mean_squared_error: 22667.2305
# Epoch 125/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90871.3125 - mean_squared_error: 41693.0781 - val_loss: 48761.9922 - val_mean_squared_error: 22682.3828
# Epoch 126/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90740.3750 - mean_squared_error: 41628.9688 - val_loss: 48822.2500 - val_mean_squared_error: 22711.1016
# Epoch 127/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90635.3750 - mean_squared_error: 41581.5000 - val_loss: 48736.2656 - val_mean_squared_error: 22670.9160
# Epoch 128/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90561.7266 - mean_squared_error: 41541.4922 - val_loss: 49127.5742 - val_mean_squared_error: 22867.1328
# Epoch 129/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 90505.9766 - mean_squared_error: 41514.1250 - val_loss: 48963.1328 - val_mean_squared_error: 22785.6602
# Epoch 130/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90413.3125 - mean_squared_error: 41472.3242 - val_loss: 49061.7344 - val_mean_squared_error: 22834.9746
# Epoch 131/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90366.5469 - mean_squared_error: 41448.9336 - val_loss: 49425.8281 - val_mean_squared_error: 23019.9258
# Epoch 132/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 90592.1875 - mean_squared_error: 41554.9766 - val_loss: 49121.9297 - val_mean_squared_error: 22869.9727
# Epoch 133/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 90492.9062 - mean_squared_error: 41509.5977 - val_loss: 49869.7969 - val_mean_squared_error: 23237.5625
# Epoch 134/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 90516.5781 - mean_squared_error: 41527.9688 - val_loss: 50308.9961 - val_mean_squared_error: 23462.7422
# Epoch 135/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 91067.2188 - mean_squared_error: 41787.6680 - val_loss: 49499.3828 - val_mean_squared_error: 23057.6641
# Epoch 136/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90770.0781 - mean_squared_error: 41656.1211 - val_loss: 50654.3867 - val_mean_squared_error: 23633.3125
# Epoch 137/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90861.6797 - mean_squared_error: 41690.6250 - val_loss: 50036.9609 - val_mean_squared_error: 23326.1543
# Epoch 138/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90824.9297 - mean_squared_error: 41672.4180 - val_loss: 50152.9375 - val_mean_squared_error: 23377.8008
# Epoch 139/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90728.4219 - mean_squared_error: 41636.2227 - val_loss: 51648.1055 - val_mean_squared_error: 24129.7930
# Epoch 140/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 91133.1328 - mean_squared_error: 41825.2344 - val_loss: 49799.4883 - val_mean_squared_error: 23209.6211
# Epoch 141/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90190.3984 - mean_squared_error: 41380.5312 - val_loss: 49477.8047 - val_mean_squared_error: 23050.8613
# Epoch 142/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 90065.7656 - mean_squared_error: 41328.7461 - val_loss: 49262.0352 - val_mean_squared_error: 22941.2305
# Epoch 143/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 89709.1641 - mean_squared_error: 41154.6445 - val_loss: 48756.3789 - val_mean_squared_error: 22693.7891
# Epoch 144/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 89366.0078 - mean_squared_error: 40993.0977 - val_loss: 48402.4805 - val_mean_squared_error: 22514.6602
# Epoch 145/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 89099.8203 - mean_squared_error: 40868.6445 - val_loss: 48652.3906 - val_mean_squared_error: 22640.9121
# Epoch 146/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 89126.4062 - mean_squared_error: 40877.5625 - val_loss: 48148.8906 - val_mean_squared_error: 22393.2852
# Epoch 147/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 88657.0469 - mean_squared_error: 40647.3828 - val_loss: 48123.1602 - val_mean_squared_error: 22381.1562
# Epoch 148/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 88702.9531 - mean_squared_error: 40665.7656 - val_loss: 48067.7695 - val_mean_squared_error: 22353.3125
# Epoch 149/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 88756.0547 - mean_squared_error: 40697.6289 - val_loss: 48351.3867 - val_mean_squared_error: 22490.8047
# Epoch 150/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 88736.6562 - mean_squared_error: 40689.1484 - val_loss: 48593.4922 - val_mean_squared_error: 22618.9453
# Epoch 151/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 88565.7266 - mean_squared_error: 40599.7656 - val_loss: 47906.8672 - val_mean_squared_error: 22277.2637
# Epoch 152/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 88214.1484 - mean_squared_error: 40435.0859 - val_loss: 48219.8672 - val_mean_squared_error: 22429.2422
# Epoch 153/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 88407.5547 - mean_squared_error: 40528.9648 - val_loss: 48071.5000 - val_mean_squared_error: 22359.4922
# Epoch 154/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 87977.5859 - mean_squared_error: 40315.8867 - val_loss: 47770.9648 - val_mean_squared_error: 22215.2305
# Epoch 155/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 87976.2812 - mean_squared_error: 40320.7148 - val_loss: 47962.5273 - val_mean_squared_error: 22305.8008
# Epoch 156/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 87559.3359 - mean_squared_error: 40119.9219 - val_loss: 48147.8945 - val_mean_squared_error: 22394.9453
# Epoch 157/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 87501.1484 - mean_squared_error: 40111.0859 - val_loss: 48014.2344 - val_mean_squared_error: 22340.2461
# Epoch 158/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 87756.3516 - mean_squared_error: 40215.7656 - val_loss: 48315.0586 - val_mean_squared_error: 22482.7148
# Epoch 159/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 87401.6406 - mean_squared_error: 40044.3711 - val_loss: 48061.0273 - val_mean_squared_error: 22360.0586
# Epoch 160/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 88193.4922 - mean_squared_error: 40477.3633 - val_loss: 50621.4883 - val_mean_squared_error: 23638.3574
# Epoch 161/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 88379.0078 - mean_squared_error: 40522.1875 - val_loss: 48508.6016 - val_mean_squared_error: 22585.3359
# Epoch 162/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 88124.3281 - mean_squared_error: 40389.9961 - val_loss: 48609.7070 - val_mean_squared_error: 22635.7070
# Epoch 163/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90003.2109 - mean_squared_error: 41348.5000 - val_loss: 50615.5195 - val_mean_squared_error: 23627.3125
# Epoch 164/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90236.0312 - mean_squared_error: 41470.4648 - val_loss: 48392.1367 - val_mean_squared_error: 22527.6621
# Epoch 165/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90802.7188 - mean_squared_error: 41767.4648 - val_loss: 49591.9219 - val_mean_squared_error: 23120.2305
# Epoch 166/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 91088.0703 - mean_squared_error: 41858.5938 - val_loss: 50122.7227 - val_mean_squared_error: 23392.9062
# Epoch 167/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 93755.2812 - mean_squared_error: 43082.6680 - val_loss: 52883.3516 - val_mean_squared_error: 24753.1133
# Epoch 168/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 97643.3359 - mean_squared_error: 44956.4375 - val_loss: 61447.2148 - val_mean_squared_error: 29032.1797
# Epoch 169/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 100210.3750 - mean_squared_error: 46233.1719 - val_loss: 53607.6211 - val_mean_squared_error: 25120.7070
# Epoch 170/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 95058.8984 - mean_squared_error: 43831.6211 - val_loss: 56718.2930 - val_mean_squared_error: 26680.8672
# Epoch 171/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 94284.3672 - mean_squared_error: 43432.7539 - val_loss: 49776.9023 - val_mean_squared_error: 23205.3906
# Epoch 172/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 90712.0703 - mean_squared_error: 41617.4609 - val_loss: 50831.2070 - val_mean_squared_error: 23751.1914
# Epoch 173/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 89736.5000 - mean_squared_error: 41203.4883 - val_loss: 48572.3750 - val_mean_squared_error: 22621.9531
# Epoch 174/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 88189.6250 - mean_squared_error: 40455.5312 - val_loss: 48044.2852 - val_mean_squared_error: 22353.6211
# Epoch 175/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 87333.9688 - mean_squared_error: 40024.8320 - val_loss: 47714.6562 - val_mean_squared_error: 22207.8828
# Epoch 176/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 86838.0234 - mean_squared_error: 39786.8125 - val_loss: 50458.7773 - val_mean_squared_error: 23561.5938
# Epoch 177/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 87109.3281 - mean_squared_error: 39918.2656 - val_loss: 48136.5820 - val_mean_squared_error: 22408.2949
# Epoch 178/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 86230.8672 - mean_squared_error: 39492.7578 - val_loss: 47159.0547 - val_mean_squared_error: 21934.5039
# Epoch 179/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 85805.8359 - mean_squared_error: 39294.6055 - val_loss: 48175.2383 - val_mean_squared_error: 22429.0859
# Epoch 180/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 85803.7031 - mean_squared_error: 39288.1680 - val_loss: 46898.5547 - val_mean_squared_error: 21804.6953
# Epoch 181/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 85334.0000 - mean_squared_error: 39075.7305 - val_loss: 47013.4844 - val_mean_squared_error: 21861.3906
# Epoch 182/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 85010.5312 - mean_squared_error: 38913.4258 - val_loss: 47223.9023 - val_mean_squared_error: 21961.8789
# Epoch 183/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 84767.8516 - mean_squared_error: 38803.6953 - val_loss: 46571.9922 - val_mean_squared_error: 21640.0527
# Epoch 184/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 84606.1484 - mean_squared_error: 38725.2617 - val_loss: 46531.4336 - val_mean_squared_error: 21622.7695
# Epoch 185/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84728.8359 - mean_squared_error: 38779.9453 - val_loss: 46829.5859 - val_mean_squared_error: 21768.6836
# Epoch 186/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84532.9141 - mean_squared_error: 38689.4297 - val_loss: 46714.3516 - val_mean_squared_error: 21717.4297
# Epoch 187/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84631.9844 - mean_squared_error: 38732.1953 - val_loss: 46743.6172 - val_mean_squared_error: 21726.6543
# Epoch 188/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84527.6875 - mean_squared_error: 38679.3281 - val_loss: 47558.7188 - val_mean_squared_error: 22117.0000
# Epoch 189/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84864.1328 - mean_squared_error: 38849.3438 - val_loss: 46981.9609 - val_mean_squared_error: 21842.3555
# Epoch 190/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84567.7266 - mean_squared_error: 38703.2031 - val_loss: 48033.1875 - val_mean_squared_error: 22361.4395
# Epoch 191/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84286.1797 - mean_squared_error: 38576.3516 - val_loss: 46841.1875 - val_mean_squared_error: 21776.7598
# Epoch 192/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 83900.7109 - mean_squared_error: 38396.8711 - val_loss: 47184.2383 - val_mean_squared_error: 21957.3379
# Epoch 193/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84657.7344 - mean_squared_error: 38757.9883 - val_loss: 47435.4297 - val_mean_squared_error: 22074.0332
# Epoch 194/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 83868.3516 - mean_squared_error: 38370.8711 - val_loss: 47167.1641 - val_mean_squared_error: 21941.6113
# Epoch 195/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 83932.3672 - mean_squared_error: 38407.1680 - val_loss: 46391.4141 - val_mean_squared_error: 21558.5859
# Epoch 196/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 83805.7812 - mean_squared_error: 38335.0664 - val_loss: 47785.8438 - val_mean_squared_error: 22238.8789
# Epoch 197/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 83223.0625 - mean_squared_error: 38060.7461 - val_loss: 47531.4961 - val_mean_squared_error: 22124.3340
# Epoch 198/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 83685.2812 - mean_squared_error: 38293.3477 - val_loss: 46645.1758 - val_mean_squared_error: 21688.0078
# Epoch 199/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 82800.5078 - mean_squared_error: 37858.4570 - val_loss: 47277.7852 - val_mean_squared_error: 22011.2930
# Epoch 200/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 84409.2500 - mean_squared_error: 38668.0352 - val_loss: 46958.0781 - val_mean_squared_error: 21856.9551
# Epoch 201/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84481.3438 - mean_squared_error: 38688.3750 - val_loss: 47419.0352 - val_mean_squared_error: 22065.3008
# Epoch 202/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84439.9688 - mean_squared_error: 38700.4570 - val_loss: 47442.1406 - val_mean_squared_error: 22077.8887
# Epoch 203/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84766.5859 - mean_squared_error: 38805.6992 - val_loss: 48741.7773 - val_mean_squared_error: 22719.2734
# Epoch 204/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84847.9453 - mean_squared_error: 38837.0703 - val_loss: 48317.5938 - val_mean_squared_error: 22517.7051
# Epoch 205/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 84472.5234 - mean_squared_error: 38668.7305 - val_loss: 47148.9570 - val_mean_squared_error: 21946.8203
# Epoch 206/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 83282.8750 - mean_squared_error: 38087.3750 - val_loss: 47348.5977 - val_mean_squared_error: 22049.0703
# Epoch 207/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 82802.8359 - mean_squared_error: 37869.7930 - val_loss: 47172.4648 - val_mean_squared_error: 21958.5645
# Epoch 208/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 82698.1172 - mean_squared_error: 37811.3945 - val_loss: 47458.7227 - val_mean_squared_error: 22100.2031
# Epoch 209/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 82808.2109 - mean_squared_error: 37877.4375 - val_loss: 49693.3047 - val_mean_squared_error: 23226.7852
# Epoch 210/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 84368.8906 - mean_squared_error: 38603.1797 - val_loss: 50070.5078 - val_mean_squared_error: 23392.8203
# Epoch 211/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84108.4453 - mean_squared_error: 38487.5586 - val_loss: 50606.0547 - val_mean_squared_error: 23671.3438
# Epoch 212/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 88792.4062 - mean_squared_error: 40763.7891 - val_loss: 49950.0508 - val_mean_squared_error: 23338.0273
# Epoch 213/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 87440.2422 - mean_squared_error: 40088.4766 - val_loss: 54241.7656 - val_mean_squared_error: 25487.3828
# Epoch 214/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 91872.1641 - mean_squared_error: 42205.8555 - val_loss: 59227.9961 - val_mean_squared_error: 27968.8125
# Epoch 215/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 92619.8281 - mean_squared_error: 42638.4609 - val_loss: 64111.4531 - val_mean_squared_error: 30414.9180
# Epoch 216/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 93413.4688 - mean_squared_error: 43072.3984 - val_loss: 47644.6211 - val_mean_squared_error: 22174.7539
# Epoch 217/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 85920.2734 - mean_squared_error: 39371.9883 - val_loss: 51721.6797 - val_mean_squared_error: 24215.1172
# Epoch 218/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 85448.6094 - mean_squared_error: 39139.7070 - val_loss: 49282.1250 - val_mean_squared_error: 23002.8184
# Epoch 219/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 86109.7422 - mean_squared_error: 39477.8047 - val_loss: 47091.5977 - val_mean_squared_error: 21922.1250
# Epoch 220/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 83132.8359 - mean_squared_error: 38049.6016 - val_loss: 45432.2734 - val_mean_squared_error: 21101.4180
# Epoch 221/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 81650.7344 - mean_squared_error: 37318.8984 - val_loss: 46701.2773 - val_mean_squared_error: 21730.5820
# Epoch 222/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 81327.1094 - mean_squared_error: 37159.1211 - val_loss: 46259.1602 - val_mean_squared_error: 21515.3184
# Epoch 223/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 81013.9375 - mean_squared_error: 37038.3164 - val_loss: 46834.0156 - val_mean_squared_error: 21799.2910
# Epoch 224/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 81056.4688 - mean_squared_error: 37057.3320 - val_loss: 45397.6875 - val_mean_squared_error: 21083.6680
# Epoch 225/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80636.3984 - mean_squared_error: 36846.2617 - val_loss: 45718.3008 - val_mean_squared_error: 21238.3965
# Epoch 226/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80188.1094 - mean_squared_error: 36623.9961 - val_loss: 45700.5430 - val_mean_squared_error: 21232.8789
# Epoch 227/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80416.7109 - mean_squared_error: 36723.2266 - val_loss: 45684.3516 - val_mean_squared_error: 21228.0801
# Epoch 228/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 79953.2969 - mean_squared_error: 36516.5352 - val_loss: 46345.3359 - val_mean_squared_error: 21552.3926
# Epoch 229/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80170.8984 - mean_squared_error: 36619.9414 - val_loss: 45771.7344 - val_mean_squared_error: 21279.8887
# Epoch 230/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 79964.9062 - mean_squared_error: 36509.8555 - val_loss: 45463.3594 - val_mean_squared_error: 21127.7266
# Epoch 231/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 79714.0078 - mean_squared_error: 36401.9258 - val_loss: 46962.6445 - val_mean_squared_error: 21868.8008
# Epoch 232/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 79960.9062 - mean_squared_error: 36533.9062 - val_loss: 45243.3867 - val_mean_squared_error: 21017.3281
# Epoch 233/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 79314.8125 - mean_squared_error: 36212.7227 - val_loss: 45508.5820 - val_mean_squared_error: 21139.2383
# Epoch 234/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80500.9609 - mean_squared_error: 36769.8164 - val_loss: 47690.1289 - val_mean_squared_error: 22214.0625
# Epoch 235/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80623.9766 - mean_squared_error: 36821.7188 - val_loss: 46578.9023 - val_mean_squared_error: 21675.5586
# Epoch 236/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 83201.0547 - mean_squared_error: 38067.7617 - val_loss: 46354.8984 - val_mean_squared_error: 21576.4824
# Epoch 237/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 83968.8516 - mean_squared_error: 38421.1406 - val_loss: 54236.5430 - val_mean_squared_error: 25496.6758
# Epoch 238/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 84478.3672 - mean_squared_error: 38682.1211 - val_loss: 50203.8008 - val_mean_squared_error: 23477.7109
# Epoch 239/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 81148.4062 - mean_squared_error: 37113.5859 - val_loss: 48701.0000 - val_mean_squared_error: 22747.1113
# Epoch 240/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 82105.8125 - mean_squared_error: 37581.9727 - val_loss: 47499.7031 - val_mean_squared_error: 22141.6934
# Epoch 241/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80207.1875 - mean_squared_error: 36665.2383 - val_loss: 47445.4219 - val_mean_squared_error: 22113.3086
# Epoch 242/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80451.3828 - mean_squared_error: 36762.0352 - val_loss: 47415.2500 - val_mean_squared_error: 22096.9590
# Epoch 243/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80672.1719 - mean_squared_error: 36866.3711 - val_loss: 46349.8438 - val_mean_squared_error: 21567.5625
# Epoch 244/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80155.0703 - mean_squared_error: 36633.6875 - val_loss: 47715.0703 - val_mean_squared_error: 22253.9688
# Epoch 245/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80451.5547 - mean_squared_error: 36770.3555 - val_loss: 48183.2227 - val_mean_squared_error: 22474.6758
# Epoch 246/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80276.7812 - mean_squared_error: 36672.2812 - val_loss: 47255.5195 - val_mean_squared_error: 22032.1660
# Epoch 247/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 81788.8516 - mean_squared_error: 37428.5781 - val_loss: 46915.0000 - val_mean_squared_error: 21843.4004
# Epoch 248/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 81170.3750 - mean_squared_error: 37156.9570 - val_loss: 48163.2227 - val_mean_squared_error: 22436.9062
# Epoch 249/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80995.1719 - mean_squared_error: 37033.3633 - val_loss: 46181.7617 - val_mean_squared_error: 21477.3945
# Epoch 250/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80149.4375 - mean_squared_error: 36625.0000 - val_loss: 46496.7891 - val_mean_squared_error: 21650.5430
# Epoch 251/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 79600.2500 - mean_squared_error: 36339.0703 - val_loss: 46072.5078 - val_mean_squared_error: 21424.1172
# Epoch 252/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 79201.8047 - mean_squared_error: 36141.4375 - val_loss: 45922.5078 - val_mean_squared_error: 21348.1074
# Epoch 253/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 78426.1953 - mean_squared_error: 35802.4023 - val_loss: 46277.8711 - val_mean_squared_error: 21542.6055
# Epoch 254/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 78347.7344 - mean_squared_error: 35755.1680 - val_loss: 46640.2852 - val_mean_squared_error: 21729.8203
# Epoch 255/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 77945.3750 - mean_squared_error: 35572.5820 - val_loss: 44972.8242 - val_mean_squared_error: 20889.5977
# Epoch 256/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 77278.6328 - mean_squared_error: 35239.7461 - val_loss: 44443.1602 - val_mean_squared_error: 20632.0996
# Epoch 257/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 78178.5547 - mean_squared_error: 35704.6992 - val_loss: 45128.0234 - val_mean_squared_error: 20975.0664
# Epoch 258/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 76737.8672 - mean_squared_error: 34974.4141 - val_loss: 44985.8242 - val_mean_squared_error: 20912.1816
# Epoch 259/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 77295.8672 - mean_squared_error: 35276.3984 - val_loss: 45276.4961 - val_mean_squared_error: 21047.5938
# Epoch 260/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 76669.0469 - mean_squared_error: 34951.5820 - val_loss: 45218.0859 - val_mean_squared_error: 21011.4805
# Epoch 261/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 78129.0156 - mean_squared_error: 35664.1992 - val_loss: 44787.8164 - val_mean_squared_error: 20803.8711
# Epoch 262/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 77240.4062 - mean_squared_error: 35228.3320 - val_loss: 46534.3203 - val_mean_squared_error: 21695.9805
# Epoch 263/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 78797.8516 - mean_squared_error: 35986.9258 - val_loss: 45486.2852 - val_mean_squared_error: 21141.6895
# Epoch 264/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 77503.4688 - mean_squared_error: 35371.3672 - val_loss: 46527.4336 - val_mean_squared_error: 21683.9336
# Epoch 265/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80271.7266 - mean_squared_error: 36664.7227 - val_loss: 47451.3125 - val_mean_squared_error: 22124.7559
# Epoch 266/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80442.0938 - mean_squared_error: 36776.3828 - val_loss: 52244.3555 - val_mean_squared_error: 24541.0430
# Epoch 267/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 80486.7266 - mean_squared_error: 36805.1523 - val_loss: 45793.0352 - val_mean_squared_error: 21293.4766
# Epoch 268/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 77124.0938 - mean_squared_error: 35201.8398 - val_loss: 45644.2031 - val_mean_squared_error: 21243.4922
# Epoch 269/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 76476.7656 - mean_squared_error: 34865.2109 - val_loss: 44751.1953 - val_mean_squared_error: 20790.3848
# Epoch 270/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 75193.9531 - mean_squared_error: 34282.5195 - val_loss: 46006.3828 - val_mean_squared_error: 21417.1387
# Epoch 271/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 76338.1250 - mean_squared_error: 34804.5508 - val_loss: 45694.9688 - val_mean_squared_error: 21258.7031
# Epoch 272/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 75913.6953 - mean_squared_error: 34609.1250 - val_loss: 44851.3711 - val_mean_squared_error: 20840.5000
# Epoch 273/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 75449.9375 - mean_squared_error: 34397.8945 - val_loss: 44856.0742 - val_mean_squared_error: 20837.4004
# Epoch 274/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 75204.7578 - mean_squared_error: 34266.3359 - val_loss: 45507.8242 - val_mean_squared_error: 21155.2383
# Epoch 275/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 74990.2891 - mean_squared_error: 34156.0938 - val_loss: 43832.7461 - val_mean_squared_error: 20339.1953
# Epoch 276/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 74295.9688 - mean_squared_error: 33842.2578 - val_loss: 46909.3633 - val_mean_squared_error: 21879.2930
# Epoch 277/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 74525.8984 - mean_squared_error: 33961.0156 - val_loss: 44611.6016 - val_mean_squared_error: 20726.3164
# Epoch 278/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 74351.7031 - mean_squared_error: 33877.0078 - val_loss: 46660.1328 - val_mean_squared_error: 21744.7656
# Epoch 279/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 75348.5312 - mean_squared_error: 34325.6719 - val_loss: 44443.9570 - val_mean_squared_error: 20657.0547
# Epoch 280/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 74147.5703 - mean_squared_error: 33779.6094 - val_loss: 46960.1328 - val_mean_squared_error: 21906.6270
# Epoch 281/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 75400.6875 - mean_squared_error: 34373.1602 - val_loss: 46189.3281 - val_mean_squared_error: 21499.1758
# Epoch 282/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 74892.4375 - mean_squared_error: 34108.4375 - val_loss: 47401.9141 - val_mean_squared_error: 22109.6211
# Epoch 283/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 75675.9531 - mean_squared_error: 34482.4844 - val_loss: 44307.9180 - val_mean_squared_error: 20582.4551
# Epoch 284/1500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 74064.0859 - mean_squared_error: 33711.1719 - val_loss: 47947.2266 - val_mean_squared_error: 22400.7871
# Epoch 285/1500

# %% [markdown]
# ##  Save trained model

# %%
model.save('Chikusei_4x__saved_model.keras')

# %% [markdown]
# ## Report the six types of results in terms of PSNR, SSIM, SAM, Correlation Coefficient, ERGAS, and RMSE.

# %%
def psnr(y_true, y_pred, max_pixel=None):
    """
    Compute PSNR for each spectral band separately and return the average.
    
    Args:
        y_true: Ground truth image, shape (H, W, B)
        y_pred: Super-resolved image, shape (H, W, B)
        max_pixel: Maximum pixel value (None = use actual max from y_true)
    
    Returns:
        Average PSNR across all bands
    """
    if max_pixel is None:
        max_pixel = np.max(y_true)  # Auto-detect max value if not provided

    B = y_true.shape[-1]  # Number of spectral bands
    psnr_values = []
    
    for i in range(B):  # Loop over bands
        mse = np.mean((y_true[..., i] - y_pred[..., i]) ** 2)
        if mse == 0:
            psnr_values.append(float('inf'))  # Perfect reconstruction
        else:
            psnr = 20 * np.log10(max_pixel / np.sqrt(mse))
            psnr_values.append(psnr)
    
    return np.mean(psnr_values)  # Average across bands

# Function to calculate SSIM with channel_axis
def ssim_value(y_true, y_pred):
    if y_true.shape != y_pred.shape:
        raise ValueError(f"Shape mismatch: y_true shape {y_true.shape} vs y_pred shape {y_pred.shape}")
    
    data_range = y_true.max() - y_true.min()  # Calculate data range from y_true
    ssim_val = ssim(y_true, y_pred, data_range=data_range, channel_axis=-1)
    return ssim_val

# Function to calculate Correlation Coefficient
def correlation_coefficient(y_true, y_pred):
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()
    corr_matrix = np.corrcoef(y_true_flat, y_pred_flat)
    corr_value = corr_matrix[0, 1]
    return corr_value

# Function to calculate Spectral Angle Mapper (SAM) in degrees
def sam(y_true, y_pred):
    y_true_reshaped = y_true.reshape(-1, y_true.shape[-1])
    y_pred_reshaped = y_pred.reshape(-1, y_pred.shape[-1])
    
    non_zero_mask = (np.linalg.norm(y_true_reshaped, axis=1) > 1e-10) & (np.linalg.norm(y_pred_reshaped, axis=1) > 1e-10)
    dot_product = np.sum(y_true_reshaped[non_zero_mask] * y_pred_reshaped[non_zero_mask], axis=1)
    norm_true = np.linalg.norm(y_true_reshaped[non_zero_mask], axis=1)
    norm_pred = np.linalg.norm(y_pred_reshaped[non_zero_mask], axis=1)
    
    with np.errstate(divide='ignore', invalid='ignore'):
        angles = np.arccos(np.clip(dot_product / (norm_true * norm_pred), -1.0, 1.0))
    
    if angles.size > 0:
        sam_value_degrees = np.mean(angles) * (180 / np.pi)
    else:
        sam_value_degrees = 0
    
    return sam_value_degrees

# Function to normalize the images
def normalize(image):
    min_val = np.min(image)
    max_val = np.max(image)
    return (image - min_val) / (max_val - min_val)  # Normalize to [0, 1]

# Function to calculate Root Mean Squared Error (RMSE) for hyperspectral images (normalized)
def rmse_bandwise(y_true, y_pred):
    if y_true.shape != y_pred.shape:
        raise ValueError("Shape mismatch between true and predicted images.")
    
    bands = y_true.shape[-1]
    rmse_per_band = []

    for b in range(bands):
        band_true = y_true[:, :, b]
        band_pred = y_pred[:, :, b]
        
        mse_band = np.mean((band_true - band_pred) ** 2)
        rmse_band_value = np.sqrt(mse_band)
        rmse_per_band.append(rmse_band_value)

    # Normalize RMSE by the maximum value in y_true across all bands
    max_value = np.max(y_true)
    normalized_rmse = np.mean(rmse_per_band) / max_value
    return normalized_rmse


# Assuming hybrid_sr_model is trained, and X_test_lr, X_test_hr are defined
predicted_hr_images =  model.predict(X_test_lr)

# Validate shapes match for test and predictions
if predicted_hr_images.shape != X_test_hr.shape:
    raise ValueError(f"Shape mismatch: predicted_hr_images shape {predicted_hr_images.shape} vs X_test_hr shape {X_test_hr.shape}")

# Calculate metrics per test sample
psnr_values, ssim_values, cc_values, sam_values, ergas_values, rmse_values = [], [], [], [], [], []

for i in range(len(X_test_hr)):
    psnr_values.append(psnr(X_test_hr[i], predicted_hr_images[i]))
    ssim_values.append(ssim_value(X_test_hr[i], predicted_hr_images[i]))
    cc_values.append(correlation_coefficient(X_test_hr[i], predicted_hr_images[i]))
    sam_values.append(sam(X_test_hr[i], predicted_hr_images[i]))
    rmse_values.append(rmse_bandwise(X_test_hr[i], predicted_hr_images[i]))

# Average metrics
average_psnr = np.mean(psnr_values)
average_ssim = np.mean(ssim_values)
average_cc = np.mean(cc_values)
average_sam = np.mean(sam_values)
average_ergas = np.mean(ergas_values)
average_rmse = np.mean(rmse_values)

# Print the evaluation metrics
print("Average PSNR on the test set:", average_psnr)
print("Average SSIM on the test set:", average_ssim)
print("Average SAM on the test set (in degrees):", average_sam)
print("Average Correlation Coefficient on the test set:", average_cc)
print("Average RMSE:", average_rmse)  # Indicate RMSE is normalizedex

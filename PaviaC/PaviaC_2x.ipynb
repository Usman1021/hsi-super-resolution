# %% [markdown]
# ## Download the dataset from the following link before using this notebook (Pavia Centre scene):

# %% [markdown]
# ##  https://www.ehu.eus/ccwintco/index.php/Hyperspectral_Remote_Sensing_Scenes

# %% [markdown]
# ## Import required libraries

# %%
import numpy as np
import h5py
import random
from scipy.io import loadmat
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, UpSampling2D, Add, Activation, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.losses import MeanSquaredError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping
from skimage.metrics import structural_similarity as ssim
# GPU setup
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("✅ GPU available. Using:", gpus[0])
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
else:
    print("❌ GPU not available. Running on CPU.")
# Out:
# 2025-07-30 19:52:32.047279: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-30 19:52:32.072678: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753894352.089254 1714045 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753894352.094644 1714045 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-30 19:52:32.113494: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✅ GPU available. Using: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# ##  Reproducibility Setup ( Set a consistent random seed for NumPy, TensorFlow, and Python's random module to ensure the same results on each run)

# %%
seed_value = 42
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)
os.environ['PYTHONHASHSEED'] = str(seed_value)

tf.config.experimental.enable_op_determinism()
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

# %% [markdown]
# ##  Load the PaviaC Dataset

# %%
data = loadmat("Pavia.mat")
if 'pavia' not in data:
    raise KeyError("'pavia' not found in the .mat file.")
hyperspectral_image = data['pavia'].astype(np.float32)

# %% [markdown]
# ##  Parameter Initialization for dataset preprocessing only

# %%
patch_size = (144, 144)
downscale_factor = 2
nodata_value = -1
group_size = 32
overlap_size = 8
validation_ratio = 0.1

# %% [markdown]
# ## Define Test Patch (Bottom-Center)

# %%
H, W, _ = hyperspectral_image.shape
patch_h, patch_w = patch_size
test_i = H - patch_h
test_j = (W - patch_w) // 2
test_coords = (test_i, test_j)

# Extract test patch
test_hr_full = hyperspectral_image[test_i:test_i + patch_h, test_j:test_j + patch_w, :]
test_lr_full = tf.image.resize(test_hr_full,
                               size=(patch_h // downscale_factor, patch_w // downscale_factor),
                               method='area').numpy()
test_hr_full = test_hr_full[np.newaxis, ...]
test_lr_full = test_lr_full[np.newaxis, ...]
# Out:
# I0000 00:00:1753894357.802039 1714045 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31141 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:8a:00.0, compute capability: 7.0

# %%
# -----------------------------
# Visualize test patch
# -----------------------------
plt.figure(figsize=(6, 6))
plt.imshow(np.mean(hyperspectral_image, axis=-1), cmap='gray')
plt.gca().add_patch(plt.Rectangle((test_j, test_i), patch_w, patch_h,
                                  edgecolor='red', facecolor='none', linewidth=2))
plt.title(f"📍 Center-Bottom Test Patch at {test_coords}")
plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Extract Training Patches

# %%
def extract_training_patches(data, patch_size, downscale_factor, nodata_value, test_coords):
    h, w, b = data.shape
    i_test, j_test = test_coords
    patch_h, patch_w = patch_size
    train_hr, train_lr = [], []

    for i in range(0, h - patch_h + 1, patch_h):
        for j in range(0, w - patch_w + 1, patch_w):
            if i == i_test and j == j_test:
                continue  # avoid test patch
            patch = data[i:i + patch_h, j:j + patch_w, :]
            if patch.shape[:2] != patch_size or np.any(patch == nodata_value):
                continue
            patch_lr = tf.image.resize(patch,
                                       size=(patch_h // downscale_factor, patch_w // downscale_factor),
                                       method='area').numpy()
            train_hr.append(patch)
            train_lr.append(patch_lr)
    return np.array(train_hr), np.array(train_lr)

train_hr_full, train_lr_full = extract_training_patches(
    hyperspectral_image, patch_size, downscale_factor, nodata_value, test_coords
)

# %% [markdown]
# ## Band grouping

# %%
def apply_band_grouping(patches, group_size, overlap_size):
    grouped = []
    for patch in patches:
        h, w, bands = patch.shape
        step = group_size - overlap_size
        for g in range(0, bands - group_size + 1, step):
            grouped_patch = patch[:, :, g:g + group_size]
            grouped.append(grouped_patch)
    return np.array(grouped)

X_train_hr = apply_band_grouping(train_hr_full, group_size, overlap_size)
X_train_lr = apply_band_grouping(train_lr_full, group_size, overlap_size)
X_test_hr = apply_band_grouping(test_hr_full, group_size, overlap_size)
X_test_lr = apply_band_grouping(test_lr_full, group_size, overlap_size)

# %% [markdown]
# ## Validation Split FOR train and validation

# %%
num_train = X_train_hr.shape[0]
val_size = max(1, int(validation_ratio * num_train))
indices = np.arange(num_train)
np.random.shuffle(indices)
X_train_hr = X_train_hr[indices]
X_train_lr = X_train_lr[indices]
X_validation_hr = X_train_hr[:val_size]
X_validation_lr = X_train_lr[:val_size]
X_train_hr = X_train_hr[val_size:]
X_train_lr = X_train_lr[val_size:]

# %% [markdown]
# ## Print database sizes to output the number of patches, patch height, width, and band group size for each subset.

# %%
print("Hyperspectral image shape:", hyperspectral_image.shape)
print("Train set (HR):", X_train_hr.shape)
print("Train set (LR):", X_train_lr.shape)
print("Validation set (HR):", X_validation_hr.shape)
print("Validation set (LR):", X_validation_lr.shape)
print("Test set (HR):", X_test_hr.shape)
print("Test set (LR):", X_test_lr.shape)
# Out:
# Hyperspectral image shape: (1096, 715, 102)
# Train set (HR): (76, 144, 144, 32)
# Train set (LR): (76, 72, 72, 32)
# Validation set (HR): (8, 144, 144, 32)
# Validation set (LR): (8, 72, 72, 32)
# Test set (HR): (3, 144, 144, 32)
# Test set (LR): (3, 72, 72, 32)

# %% [markdown]
# ##  Model development

# %%
# -----------------------------
# Custom Loss Function: Spatial + Spectral Gradient + MSE
# -----------------------------
def spatial_spectral_gradient_loss(weight_mse=1.0, weight_spatial=0.1, weight_spectral=0.1):
    def loss_fn(y_true, y_pred):
        mse_loss = K.mean(K.square(y_true - y_pred))

        grad_true_x = y_true[:, 1:, :, :] - y_true[:, :-1, :, :]
        grad_pred_x = y_pred[:, 1:, :, :] - y_pred[:, :-1, :, :]
        grad_true_y = y_true[:, :, 1:, :] - y_true[:, :, :-1, :]
        grad_pred_y = y_pred[:, :, 1:, :] - y_pred[:, :, :-1, :]
        spatial_loss = K.mean(K.square(grad_true_x - grad_pred_x)) + K.mean(K.square(grad_true_y - grad_pred_y))

        grad_true_s = y_true[:, :, :, 1:] - y_true[:, :, :, :-1]
        grad_pred_s = y_pred[:, :, :, 1:] - y_pred[:, :, :, :-1]
        spectral_loss = K.mean(K.square(grad_true_s - grad_pred_s))

        return weight_mse * mse_loss + weight_spatial * spatial_loss + weight_spectral * spectral_loss

    return loss_fn

# -----------------------------
# Residual Block
# -----------------------------
def resnet_block(x, filters):
    shortcut = x
    x = Conv2D(filters, 3, padding='same', activation='relu')(x)
    x = Conv2D(filters, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# -----------------------------
# Spectral Unmixing Block
# -----------------------------
def spectral_unmixing_block(x, filters):
    x = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)
    x = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)
    return x

# -----------------------------
# Spectral–Spatial Fusion Block
# -----------------------------
def spectral_spatial_fusion_block(x, filters):
    spatial = Conv2D(filters, kernel_size=3, padding='same', activation='relu')(x)
    spectral = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)
    fused = Concatenate()([spatial, spectral])
    fused = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(fused)
    return fused

# -----------------------------
# Model Architecture (Fully Convolutional)
# -----------------------------
def build_simple_sr_model(input_shape=(None, None, 128)):
    inputs = Input(shape=input_shape)

    # Pre-Upsampling
    x = UpSampling2D(size=(2, 2), interpolation='bilinear')(inputs)

    x = spectral_unmixing_block(x, filters=64)
    x = spectral_spatial_fusion_block(x, filters=64)
    x = Conv2D(64, 3, padding='same', activation='relu')(x)

    for _ in range(3):
        x = resnet_block(x, 64)

    output = Conv2D(input_shape[-1], 3, padding='same', activation='linear')(x)

    return Model(inputs, output, name='SR_Model_PreUpsampling')

# -----------------------------
# Build and Compile Model
# -----------------------------
model = build_simple_sr_model(input_shape=(None, None, 32))

model.compile(
    optimizer='adam',
    loss=spatial_spectral_gradient_loss(
        weight_mse=2.0,
        weight_spatial=0.1,
        weight_spectral=0.1
    ),
    metrics=[MeanSquaredError()]
)

# -----------------------------
# Parameter Count
# -----------------------------
total_params = model.count_params()
size_in_bytes = total_params * 4
size_in_mb = size_in_bytes / (1024 ** 2)

print(f"📢 Model size: {size_in_mb:.2f} MB")
print(f"📊 Total Parameters: {total_params / 1e6:.2f} Million")
# Out:
# 📢 Model size: 1.27 MB
# 📊 Total Parameters: 0.33 Million

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Train the model and get the training history with early stopping
history = model.fit(
    X_train_lr, 
    X_train_hr, 
    epochs=1000, 
    batch_size=4, 
    validation_data=(X_validation_lr, X_validation_hr),
    callbacks=[early_stopping]  # Add the early stopping callback here
)

# Visualize training and validation loss over epochs
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)  # Add grid for better readability
plt.show()
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753894364.857886 1714127 service.cc:148] XLA service 0x7f45dc013bd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753894364.874279 1714127 service.cc:156]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2025-07-30 19:52:45.399025: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1753894366.025134 1714127 cuda_dnn.cc:529] Loaded cuDNN version 90501
#  6/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2547487.2500 - mean_squared_error: 1256691.1250
# I0000 00:00:1753894371.822525 1714127 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - loss: 1605356.3750 - mean_squared_error: 784147.8125 - val_loss: 152220.8594 - val_mean_squared_error: 69865.9922
# Epoch 2/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 286989.6875 - mean_squared_error: 133257.9219 - val_loss: 109856.2344 - val_mean_squared_error: 49780.8594
# Epoch 3/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 188387.7500 - mean_squared_error: 85501.2969 - val_loss: 78668.4531 - val_mean_squared_error: 34789.4766
# Epoch 4/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 140481.8594 - mean_squared_error: 62787.5977 - val_loss: 67680.8750 - val_mean_squared_error: 29632.5801
# Epoch 5/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 121569.3438 - mean_squared_error: 53934.1484 - val_loss: 66920.3828 - val_mean_squared_error: 29425.8125
# Epoch 6/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 107405.0000 - mean_squared_error: 47216.8594 - val_loss: 56074.7539 - val_mean_squared_error: 24148.2617
# Epoch 7/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 93219.3516 - mean_squared_error: 40452.2734 - val_loss: 52427.2188 - val_mean_squared_error: 22492.0938
# Epoch 8/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 86231.0625 - mean_squared_error: 37294.7969 - val_loss: 49505.1953 - val_mean_squared_error: 21165.1211
# Epoch 9/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 84738.9766 - mean_squared_error: 36747.0234 - val_loss: 47563.1250 - val_mean_squared_error: 20282.0039
# Epoch 10/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 76810.1406 - mean_squared_error: 32982.4414 - val_loss: 45551.6016 - val_mean_squared_error: 19365.4062
# Epoch 11/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 73508.5000 - mean_squared_error: 31495.8398 - val_loss: 44679.0391 - val_mean_squared_error: 18983.3223
# Epoch 12/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 75120.2500 - mean_squared_error: 32399.5273 - val_loss: 44908.3438 - val_mean_squared_error: 19134.6367
# Epoch 13/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 72557.0078 - mean_squared_error: 31207.2617 - val_loss: 43555.7891 - val_mean_squared_error: 18503.1973
# Epoch 14/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 68390.1719 - mean_squared_error: 29208.3027 - val_loss: 42205.4375 - val_mean_squared_error: 17865.6914
# Epoch 15/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 66309.7422 - mean_squared_error: 28247.7051 - val_loss: 41503.5547 - val_mean_squared_error: 17549.1680
# Epoch 16/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 64495.0000 - mean_squared_error: 27411.8691 - val_loss: 41022.7539 - val_mean_squared_error: 17338.7969
# Epoch 17/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 64003.0430 - mean_squared_error: 27225.1387 - val_loss: 40485.3516 - val_mean_squared_error: 17096.3281
# Epoch 18/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 62675.5977 - mean_squared_error: 26619.9082 - val_loss: 40417.3984 - val_mean_squared_error: 17086.4609
# Epoch 19/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 63480.6797 - mean_squared_error: 27070.2402 - val_loss: 39739.6562 - val_mean_squared_error: 16766.2109
# Epoch 20/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 64194.4922 - mean_squared_error: 27464.9551 - val_loss: 40191.4531 - val_mean_squared_error: 17003.1523
# Epoch 21/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 63109.8828 - mean_squared_error: 26965.0664 - val_loss: 39736.9766 - val_mean_squared_error: 16805.6465
# Epoch 22/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 64720.4297 - mean_squared_error: 27792.9512 - val_loss: 39694.4688 - val_mean_squared_error: 16797.6152
# Epoch 23/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 61763.5469 - mean_squared_error: 26353.4434 - val_loss: 39216.4453 - val_mean_squared_error: 16574.7598
# Epoch 24/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 59975.7070 - mean_squared_error: 25512.2207 - val_loss: 38502.2656 - val_mean_squared_error: 16236.3965
# Epoch 25/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 58533.8633 - mean_squared_error: 24830.4043 - val_loss: 38228.8086 - val_mean_squared_error: 16113.8457
# Epoch 26/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 58240.8203 - mean_squared_error: 24721.9980 - val_loss: 38275.8867 - val_mean_squared_error: 16155.6221
# Epoch 27/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 57681.9023 - mean_squared_error: 24481.6016 - val_loss: 37892.9961 - val_mean_squared_error: 15987.5479
# Epoch 28/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 56832.7188 - mean_squared_error: 24094.2402 - val_loss: 37027.0273 - val_mean_squared_error: 15567.6270
# Epoch 29/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 55397.0078 - mean_squared_error: 23411.2285 - val_loss: 36572.1953 - val_mean_squared_error: 15364.1328
# Epoch 30/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 55213.6055 - mean_squared_error: 23354.9102 - val_loss: 36789.3164 - val_mean_squared_error: 15473.6914
# Epoch 31/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 54969.0156 - mean_squared_error: 23257.6406 - val_loss: 36182.2148 - val_mean_squared_error: 15199.1055
# Epoch 32/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 56433.5742 - mean_squared_error: 24016.0508 - val_loss: 36544.6719 - val_mean_squared_error: 15369.6709
# Epoch 33/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 57342.1914 - mean_squared_error: 24469.4473 - val_loss: 36048.3750 - val_mean_squared_error: 15154.5723
# Epoch 34/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 57741.1992 - mean_squared_error: 24682.0898 - val_loss: 35843.6250 - val_mean_squared_error: 15057.1875
# Epoch 35/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 53386.6523 - mean_squared_error: 22552.7773 - val_loss: 35671.9688 - val_mean_squared_error: 14997.2734
# Epoch 36/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 53248.1484 - mean_squared_error: 22525.5547 - val_loss: 35316.3594 - val_mean_squared_error: 14830.8320
# Epoch 37/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 52223.5586 - mean_squared_error: 22049.0078 - val_loss: 35081.8945 - val_mean_squared_error: 14730.9688
# Epoch 38/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 51892.9453 - mean_squared_error: 21911.9453 - val_loss: 34867.3125 - val_mean_squared_error: 14635.6973
# Epoch 39/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 51430.6172 - mean_squared_error: 21708.6836 - val_loss: 34604.3906 - val_mean_squared_error: 14522.1260
# Epoch 40/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 51475.2500 - mean_squared_error: 21753.4512 - val_loss: 34668.0703 - val_mean_squared_error: 14556.1016
# Epoch 41/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 50880.0625 - mean_squared_error: 21477.9902 - val_loss: 34297.3945 - val_mean_squared_error: 14387.4307
# Epoch 42/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 51276.3320 - mean_squared_error: 21694.3535 - val_loss: 34472.2695 - val_mean_squared_error: 14476.0049
# Epoch 43/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 50335.0586 - mean_squared_error: 21247.4004 - val_loss: 34004.5312 - val_mean_squared_error: 14256.9756
# Epoch 44/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 51035.5234 - mean_squared_error: 21609.1211 - val_loss: 34619.4961 - val_mean_squared_error: 14558.0127
# Epoch 45/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 50724.3672 - mean_squared_error: 21475.1641 - val_loss: 33943.1328 - val_mean_squared_error: 14239.0625
# Epoch 46/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 52935.7891 - mean_squared_error: 22579.5977 - val_loss: 34277.2539 - val_mean_squared_error: 14391.4268
# Epoch 47/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 53344.1953 - mean_squared_error: 22778.7266 - val_loss: 34887.5859 - val_mean_squared_error: 14727.3340
# Epoch 48/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 53285.8086 - mean_squared_error: 22776.2793 - val_loss: 33827.8594 - val_mean_squared_error: 14189.7607
# Epoch 49/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 49053.8711 - mean_squared_error: 20694.4941 - val_loss: 33452.0938 - val_mean_squared_error: 14019.3174
# Epoch 50/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 48494.0117 - mean_squared_error: 20440.3477 - val_loss: 33121.3125 - val_mean_squared_error: 13867.9287
# Epoch 51/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 47749.0898 - mean_squared_error: 20095.3398 - val_loss: 32925.5859 - val_mean_squared_error: 13781.3262
# Epoch 52/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 47772.4297 - mean_squared_error: 20124.9492 - val_loss: 33002.1094 - val_mean_squared_error: 13822.2109
# Epoch 53/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 47447.9453 - mean_squared_error: 19979.2422 - val_loss: 32758.3750 - val_mean_squared_error: 13709.3408
# Epoch 54/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 48050.5820 - mean_squared_error: 20292.2227 - val_loss: 33311.0000 - val_mean_squared_error: 13973.1592
# Epoch 55/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 48129.6055 - mean_squared_error: 20345.9590 - val_loss: 32992.8398 - val_mean_squared_error: 13834.3848
# Epoch 56/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 50551.2891 - mean_squared_error: 21551.2637 - val_loss: 33009.1016 - val_mean_squared_error: 13835.2070
# Epoch 57/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 49419.8398 - mean_squared_error: 21000.3203 - val_loss: 33305.2734 - val_mean_squared_error: 14001.4219
# Epoch 58/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 49553.6914 - mean_squared_error: 21081.4766 - val_loss: 32622.4336 - val_mean_squared_error: 13653.6738
# Epoch 59/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 46289.0703 - mean_squared_error: 19475.5684 - val_loss: 32586.0879 - val_mean_squared_error: 13645.6543
# Epoch 60/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 46470.1016 - mean_squared_error: 19573.8535 - val_loss: 32379.0723 - val_mean_squared_error: 13548.9082
# Epoch 61/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 45663.3906 - mean_squared_error: 19198.0020 - val_loss: 32247.7969 - val_mean_squared_error: 13489.3203
# Epoch 62/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 45697.7148 - mean_squared_error: 19230.6250 - val_loss: 32162.6719 - val_mean_squared_error: 13450.2012
# Epoch 63/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 45274.7031 - mean_squared_error: 19036.5527 - val_loss: 32175.2402 - val_mean_squared_error: 13460.0176
# Epoch 64/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 45903.0938 - mean_squared_error: 19363.2148 - val_loss: 32348.7910 - val_mean_squared_error: 13548.0205
# Epoch 65/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 45848.9570 - mean_squared_error: 19345.8730 - val_loss: 32254.9219 - val_mean_squared_error: 13503.2012
# Epoch 66/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 48539.4883 - mean_squared_error: 20685.4199 - val_loss: 32550.0078 - val_mean_squared_error: 13642.4043
# Epoch 67/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 49748.3359 - mean_squared_error: 21274.9922 - val_loss: 34396.3633 - val_mean_squared_error: 14545.1416
# Epoch 68/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 51539.1719 - mean_squared_error: 22146.7773 - val_loss: 32567.7344 - val_mean_squared_error: 13653.7051
# Epoch 69/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 45360.1367 - mean_squared_error: 19111.8066 - val_loss: 32721.1719 - val_mean_squared_error: 13736.9180
# Epoch 70/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 45228.0195 - mean_squared_error: 19071.7969 - val_loss: 32113.1797 - val_mean_squared_error: 13439.7695
# Epoch 71/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 44159.4023 - mean_squared_error: 18563.2441 - val_loss: 32088.9727 - val_mean_squared_error: 13433.6562
# Epoch 72/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 43921.3672 - mean_squared_error: 18467.8008 - val_loss: 31509.0957 - val_mean_squared_error: 13169.5928
# Epoch 73/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 43303.5898 - mean_squared_error: 18183.6992 - val_loss: 31710.6035 - val_mean_squared_error: 13268.4619
# Epoch 74/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 43298.4219 - mean_squared_error: 18192.6992 - val_loss: 31593.7637 - val_mean_squared_error: 13213.8398
# Epoch 75/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 43099.4922 - mean_squared_error: 18105.4746 - val_loss: 31650.9473 - val_mean_squared_error: 13239.5098
# Epoch 76/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42883.2188 - mean_squared_error: 18012.5996 - val_loss: 31856.6602 - val_mean_squared_error: 13327.5049
# Epoch 77/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 43132.2344 - mean_squared_error: 18137.9883 - val_loss: 31804.1914 - val_mean_squared_error: 13317.4902
# Epoch 78/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42905.1797 - mean_squared_error: 18034.6230 - val_loss: 31438.0898 - val_mean_squared_error: 13142.8418
# Epoch 79/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42795.2539 - mean_squared_error: 17986.0156 - val_loss: 31570.4766 - val_mean_squared_error: 13208.3164
# Epoch 80/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42350.1484 - mean_squared_error: 17779.7988 - val_loss: 31416.2617 - val_mean_squared_error: 13130.5215
# Epoch 81/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42427.1016 - mean_squared_error: 17825.2109 - val_loss: 31483.2227 - val_mean_squared_error: 13165.5732
# Epoch 82/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42648.5508 - mean_squared_error: 17943.1602 - val_loss: 31579.7832 - val_mean_squared_error: 13214.5527
# Epoch 83/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42443.3242 - mean_squared_error: 17848.7598 - val_loss: 31668.9160 - val_mean_squared_error: 13263.3457
# Epoch 84/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42225.3047 - mean_squared_error: 17745.5195 - val_loss: 31697.7383 - val_mean_squared_error: 13287.2031
# Epoch 85/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42372.6719 - mean_squared_error: 17819.4727 - val_loss: 32336.1992 - val_mean_squared_error: 13593.3242
# Epoch 86/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 43022.6719 - mean_squared_error: 18153.7891 - val_loss: 32819.5703 - val_mean_squared_error: 13845.5273
# Epoch 87/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 44090.3086 - mean_squared_error: 18668.2520 - val_loss: 31339.5781 - val_mean_squared_error: 13105.9863
# Epoch 88/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42248.5391 - mean_squared_error: 17774.7812 - val_loss: 31592.2070 - val_mean_squared_error: 13248.4688
# Epoch 89/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42649.8828 - mean_squared_error: 17999.6855 - val_loss: 31979.1270 - val_mean_squared_error: 13432.9336
# Epoch 90/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 46476.2305 - mean_squared_error: 19892.5586 - val_loss: 31533.8320 - val_mean_squared_error: 13223.5391
# Epoch 91/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41664.9375 - mean_squared_error: 17522.0508 - val_loss: 31089.9375 - val_mean_squared_error: 13012.6445
# Epoch 92/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41070.4062 - mean_squared_error: 17248.1309 - val_loss: 30857.6055 - val_mean_squared_error: 12894.5137
# Epoch 93/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 40691.3984 - mean_squared_error: 17077.8535 - val_loss: 30668.9766 - val_mean_squared_error: 12816.7715
# Epoch 94/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 40487.3945 - mean_squared_error: 16995.2031 - val_loss: 30664.3984 - val_mean_squared_error: 12809.6270
# Epoch 95/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 40560.4375 - mean_squared_error: 17037.6348 - val_loss: 30970.6992 - val_mean_squared_error: 12950.1875
# Epoch 96/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41163.5273 - mean_squared_error: 17335.5781 - val_loss: 31335.0977 - val_mean_squared_error: 13122.0117
# Epoch 97/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42333.2188 - mean_squared_error: 17917.4316 - val_loss: 31096.9902 - val_mean_squared_error: 13007.1602
# Epoch 98/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42541.9766 - mean_squared_error: 18012.5312 - val_loss: 31931.5977 - val_mean_squared_error: 13429.3203
# Epoch 99/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41357.3633 - mean_squared_error: 17434.9961 - val_loss: 32693.8164 - val_mean_squared_error: 13816.9512
# Epoch 100/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42444.4727 - mean_squared_error: 17978.1660 - val_loss: 32351.3906 - val_mean_squared_error: 13627.8496
# Epoch 101/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 43288.5078 - mean_squared_error: 18365.9180 - val_loss: 30655.0078 - val_mean_squared_error: 12806.3242
# Epoch 102/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 40533.6211 - mean_squared_error: 17029.0488 - val_loss: 31613.1387 - val_mean_squared_error: 13264.2227
# Epoch 103/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42269.4648 - mean_squared_error: 17899.7734 - val_loss: 32236.3164 - val_mean_squared_error: 13528.8320
# Epoch 104/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 44522.2266 - mean_squared_error: 18989.8867 - val_loss: 31512.8984 - val_mean_squared_error: 13237.2363
# Epoch 105/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41069.3164 - mean_squared_error: 17298.1523 - val_loss: 30785.2383 - val_mean_squared_error: 12880.9590
# Epoch 106/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 40423.8633 - mean_squared_error: 17008.2637 - val_loss: 30750.9688 - val_mean_squared_error: 12843.4766
# Epoch 107/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39566.0703 - mean_squared_error: 16605.0352 - val_loss: 30659.0117 - val_mean_squared_error: 12803.0088
# Epoch 108/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39650.1719 - mean_squared_error: 16665.3418 - val_loss: 30486.1797 - val_mean_squared_error: 12731.7832
# Epoch 109/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39729.4727 - mean_squared_error: 16720.4941 - val_loss: 30517.3984 - val_mean_squared_error: 12749.2393
# Epoch 110/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39371.8711 - mean_squared_error: 16549.4551 - val_loss: 30813.2344 - val_mean_squared_error: 12889.9961
# Epoch 111/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39186.0156 - mean_squared_error: 16460.4609 - val_loss: 31386.1016 - val_mean_squared_error: 13169.0684
# Epoch 112/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39250.4180 - mean_squared_error: 16504.1270 - val_loss: 32753.6406 - val_mean_squared_error: 13850.2305
# Epoch 113/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41227.4102 - mean_squared_error: 17466.8789 - val_loss: 33745.5391 - val_mean_squared_error: 14349.0801
# Epoch 114/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 43759.0938 - mean_squared_error: 18700.7520 - val_loss: 30839.8711 - val_mean_squared_error: 12897.5723
# Epoch 115/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39857.1523 - mean_squared_error: 16782.1719 - val_loss: 31157.8555 - val_mean_squared_error: 13090.0723
# Epoch 116/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 40426.4453 - mean_squared_error: 17077.9434 - val_loss: 31493.4102 - val_mean_squared_error: 13213.6318
# Epoch 117/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41689.8164 - mean_squared_error: 17710.2344 - val_loss: 31386.5391 - val_mean_squared_error: 13147.4141
# Epoch 118/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39501.8945 - mean_squared_error: 16633.3086 - val_loss: 31954.1875 - val_mean_squared_error: 13492.9512
# Epoch 119/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39901.2930 - mean_squared_error: 16854.7637 - val_loss: 30333.6113 - val_mean_squared_error: 12685.2520
# Epoch 120/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39237.9453 - mean_squared_error: 16539.6016 - val_loss: 30191.4023 - val_mean_squared_error: 12618.8750
# Epoch 121/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 38253.6562 - mean_squared_error: 16067.1309 - val_loss: 30400.4102 - val_mean_squared_error: 12706.3105
# Epoch 122/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39030.3203 - mean_squared_error: 16453.8242 - val_loss: 30423.6094 - val_mean_squared_error: 12702.6592
# Epoch 123/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39601.2070 - mean_squared_error: 16728.4043 - val_loss: 31246.1738 - val_mean_squared_error: 13069.3340
# Epoch 124/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39345.8359 - mean_squared_error: 16573.9922 - val_loss: 31768.0898 - val_mean_squared_error: 13342.8027
# Epoch 125/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39666.2539 - mean_squared_error: 16730.9434 - val_loss: 31925.3320 - val_mean_squared_error: 13504.6016
# Epoch 126/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41339.2695 - mean_squared_error: 17566.8145 - val_loss: 30842.9785 - val_mean_squared_error: 12953.8320
# Epoch 127/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 40233.7344 - mean_squared_error: 17037.6035 - val_loss: 32027.7578 - val_mean_squared_error: 13480.6035
# Epoch 128/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39881.4336 - mean_squared_error: 16854.7988 - val_loss: 33394.9609 - val_mean_squared_error: 14123.9746
# Epoch 129/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 44975.2852 - mean_squared_error: 19364.2695 - val_loss: 30397.3750 - val_mean_squared_error: 12714.0986
# Epoch 130/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41375.3750 - mean_squared_error: 17595.6777 - val_loss: 32631.6250 - val_mean_squared_error: 13842.9131
# Epoch 131/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41943.6016 - mean_squared_error: 17906.9980 - val_loss: 30664.1621 - val_mean_squared_error: 12829.2910
# Epoch 132/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41793.1133 - mean_squared_error: 17840.2695 - val_loss: 30439.5586 - val_mean_squared_error: 12761.3281
# Epoch 133/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41458.2539 - mean_squared_error: 17690.1406 - val_loss: 30621.6895 - val_mean_squared_error: 12832.5557
# Epoch 134/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42642.8828 - mean_squared_error: 18281.2422 - val_loss: 30262.6406 - val_mean_squared_error: 12644.9854
# Epoch 135/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37940.4102 - mean_squared_error: 15939.8574 - val_loss: 30339.3359 - val_mean_squared_error: 12683.3711
# Epoch 136/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37245.2734 - mean_squared_error: 15634.2861 - val_loss: 29401.8711 - val_mean_squared_error: 12263.9453
# Epoch 137/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37395.6641 - mean_squared_error: 15699.7725 - val_loss: 30090.0820 - val_mean_squared_error: 12563.7520
# Epoch 138/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36942.7109 - mean_squared_error: 15501.1445 - val_loss: 30061.0801 - val_mean_squared_error: 12551.6338
# Epoch 139/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37314.8984 - mean_squared_error: 15684.0459 - val_loss: 29815.6797 - val_mean_squared_error: 12463.3398
# Epoch 140/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37273.1055 - mean_squared_error: 15671.0625 - val_loss: 30481.6562 - val_mean_squared_error: 12728.8047
# Epoch 141/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37961.0117 - mean_squared_error: 16007.9883 - val_loss: 29931.4570 - val_mean_squared_error: 12515.1582
# Epoch 142/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 38673.3945 - mean_squared_error: 16329.5635 - val_loss: 31416.3926 - val_mean_squared_error: 13126.6396
# Epoch 143/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 41706.2344 - mean_squared_error: 17783.3066 - val_loss: 30580.4062 - val_mean_squared_error: 12819.8672
# Epoch 144/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 40349.8711 - mean_squared_error: 17157.1367 - val_loss: 30781.8516 - val_mean_squared_error: 12902.6260
# Epoch 145/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42183.7891 - mean_squared_error: 18077.3516 - val_loss: 30584.3008 - val_mean_squared_error: 12764.7617
# Epoch 146/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37416.6562 - mean_squared_error: 15722.9844 - val_loss: 30248.9414 - val_mean_squared_error: 12642.6680
# Epoch 147/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36661.8008 - mean_squared_error: 15398.6895 - val_loss: 29521.5781 - val_mean_squared_error: 12318.9707
# Epoch 148/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36509.1875 - mean_squared_error: 15344.9268 - val_loss: 29467.7715 - val_mean_squared_error: 12292.4121
# Epoch 149/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35788.6367 - mean_squared_error: 15010.2783 - val_loss: 29216.9355 - val_mean_squared_error: 12188.0615
# Epoch 150/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36126.4922 - mean_squared_error: 15188.7051 - val_loss: 29010.8203 - val_mean_squared_error: 12107.9746
# Epoch 151/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35888.9023 - mean_squared_error: 15083.9102 - val_loss: 29338.8203 - val_mean_squared_error: 12241.0078
# Epoch 152/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37098.6602 - mean_squared_error: 15678.3047 - val_loss: 29173.1348 - val_mean_squared_error: 12182.6777
# Epoch 153/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36797.1289 - mean_squared_error: 15537.9805 - val_loss: 29554.4453 - val_mean_squared_error: 12341.0977
# Epoch 154/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 38958.7227 - mean_squared_error: 16600.9805 - val_loss: 29146.6328 - val_mean_squared_error: 12163.4697
# Epoch 155/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36618.9766 - mean_squared_error: 15444.8730 - val_loss: 29692.9297 - val_mean_squared_error: 12411.6299
# Epoch 156/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37347.4258 - mean_squared_error: 15804.4580 - val_loss: 29221.7637 - val_mean_squared_error: 12187.5752
# Epoch 157/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35694.3086 - mean_squared_error: 14979.3584 - val_loss: 29640.3594 - val_mean_squared_error: 12385.0195
# Epoch 158/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36140.9961 - mean_squared_error: 15211.1904 - val_loss: 29524.0020 - val_mean_squared_error: 12345.9043
# Epoch 159/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35953.5195 - mean_squared_error: 15112.1895 - val_loss: 29103.3711 - val_mean_squared_error: 12149.4082
# Epoch 160/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35984.0195 - mean_squared_error: 15136.7188 - val_loss: 29683.9414 - val_mean_squared_error: 12412.4307
# Epoch 161/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36171.0039 - mean_squared_error: 15205.7939 - val_loss: 29337.0918 - val_mean_squared_error: 12248.0391
# Epoch 162/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36265.9141 - mean_squared_error: 15279.5479 - val_loss: 29428.3262 - val_mean_squared_error: 12295.5645
# Epoch 163/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35905.9414 - mean_squared_error: 15121.6768 - val_loss: 29028.2891 - val_mean_squared_error: 12100.8223
# Epoch 164/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36843.3789 - mean_squared_error: 15587.8936 - val_loss: 29441.1641 - val_mean_squared_error: 12317.1406
# Epoch 165/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36824.4023 - mean_squared_error: 15558.0537 - val_loss: 29529.7461 - val_mean_squared_error: 12329.9756
# Epoch 166/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 38631.6016 - mean_squared_error: 16432.4453 - val_loss: 29772.7734 - val_mean_squared_error: 12451.5508
# Epoch 167/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37596.6641 - mean_squared_error: 15907.5811 - val_loss: 30580.1836 - val_mean_squared_error: 12842.2773
# Epoch 168/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 39040.1250 - mean_squared_error: 16637.3691 - val_loss: 28960.9453 - val_mean_squared_error: 12078.5020
# Epoch 169/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35215.9297 - mean_squared_error: 14781.3496 - val_loss: 29689.1914 - val_mean_squared_error: 12430.5215
# Epoch 170/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35741.5742 - mean_squared_error: 15068.3838 - val_loss: 29023.2930 - val_mean_squared_error: 12114.6826
# Epoch 171/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34766.1094 - mean_squared_error: 14596.4277 - val_loss: 29298.3438 - val_mean_squared_error: 12248.3223
# Epoch 172/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34836.4805 - mean_squared_error: 14635.9512 - val_loss: 29429.2988 - val_mean_squared_error: 12292.1729
# Epoch 173/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34832.7070 - mean_squared_error: 14624.5869 - val_loss: 29246.0879 - val_mean_squared_error: 12208.9609
# Epoch 174/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35065.7188 - mean_squared_error: 14733.7588 - val_loss: 29791.7012 - val_mean_squared_error: 12456.6494
# Epoch 175/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35075.6445 - mean_squared_error: 14730.1895 - val_loss: 29069.4648 - val_mean_squared_error: 12139.1348
# Epoch 176/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35721.8125 - mean_squared_error: 15036.7217 - val_loss: 29329.8613 - val_mean_squared_error: 12268.4678
# Epoch 177/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35277.3438 - mean_squared_error: 14831.5557 - val_loss: 28928.1797 - val_mean_squared_error: 12054.4121
# Epoch 178/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35017.4492 - mean_squared_error: 14695.4141 - val_loss: 29195.1016 - val_mean_squared_error: 12188.0449
# Epoch 179/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34960.5586 - mean_squared_error: 14674.5264 - val_loss: 29184.3887 - val_mean_squared_error: 12180.5938
# Epoch 180/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34930.1758 - mean_squared_error: 14659.6426 - val_loss: 28881.2852 - val_mean_squared_error: 12054.0391
# Epoch 181/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35043.1797 - mean_squared_error: 14709.9131 - val_loss: 29241.0664 - val_mean_squared_error: 12243.0029
# Epoch 182/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35213.2109 - mean_squared_error: 14791.6084 - val_loss: 30454.2676 - val_mean_squared_error: 12807.0078
# Epoch 183/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35646.3555 - mean_squared_error: 15021.0674 - val_loss: 28819.1484 - val_mean_squared_error: 12037.6953
# Epoch 184/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34722.1602 - mean_squared_error: 14587.0762 - val_loss: 28897.6875 - val_mean_squared_error: 12041.8330
# Epoch 185/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34641.8789 - mean_squared_error: 14563.7578 - val_loss: 29880.3750 - val_mean_squared_error: 12500.0195
# Epoch 186/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37940.6289 - mean_squared_error: 16193.8252 - val_loss: 29631.2285 - val_mean_squared_error: 12384.5762
# Epoch 187/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35796.6680 - mean_squared_error: 15131.5459 - val_loss: 31134.1914 - val_mean_squared_error: 13160.6240
# Epoch 188/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35832.6445 - mean_squared_error: 15169.8613 - val_loss: 28451.7891 - val_mean_squared_error: 11852.2773
# Epoch 189/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33644.7539 - mean_squared_error: 14113.7793 - val_loss: 28702.7812 - val_mean_squared_error: 11957.0254
# Epoch 190/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33402.8984 - mean_squared_error: 14010.6172 - val_loss: 28885.5117 - val_mean_squared_error: 12031.9199
# Epoch 191/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33278.5078 - mean_squared_error: 13950.8867 - val_loss: 28704.1445 - val_mean_squared_error: 11954.7598
# Epoch 192/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33157.4062 - mean_squared_error: 13899.9238 - val_loss: 28862.0156 - val_mean_squared_error: 12040.6631
# Epoch 193/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33179.4062 - mean_squared_error: 13913.1230 - val_loss: 29752.5117 - val_mean_squared_error: 12467.9844
# Epoch 194/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33848.2422 - mean_squared_error: 14247.6885 - val_loss: 29734.1816 - val_mean_squared_error: 12463.2324
# Epoch 195/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34950.5078 - mean_squared_error: 14775.8740 - val_loss: 29063.5352 - val_mean_squared_error: 12115.4297
# Epoch 196/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34149.0000 - mean_squared_error: 14367.0078 - val_loss: 30196.0859 - val_mean_squared_error: 12662.3945
# Epoch 197/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35309.4023 - mean_squared_error: 14924.9756 - val_loss: 31716.8770 - val_mean_squared_error: 13342.7031
# Epoch 198/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 40979.6641 - mean_squared_error: 17665.5098 - val_loss: 30927.1504 - val_mean_squared_error: 13002.9121
# Epoch 199/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35697.6484 - mean_squared_error: 15065.7090 - val_loss: 30283.0703 - val_mean_squared_error: 12678.1611
# Epoch 200/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35091.3672 - mean_squared_error: 14788.0029 - val_loss: 29720.1641 - val_mean_squared_error: 12403.7061
# Epoch 201/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34096.6250 - mean_squared_error: 14338.6016 - val_loss: 28885.7695 - val_mean_squared_error: 12037.1016
# Epoch 202/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33222.5234 - mean_squared_error: 13938.5566 - val_loss: 29313.3906 - val_mean_squared_error: 12223.6699
# Epoch 203/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33316.8008 - mean_squared_error: 13976.4229 - val_loss: 29233.8477 - val_mean_squared_error: 12192.3633
# Epoch 204/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33357.1289 - mean_squared_error: 13994.5713 - val_loss: 29182.9297 - val_mean_squared_error: 12167.5938
# Epoch 205/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33487.5820 - mean_squared_error: 14056.1279 - val_loss: 29503.2500 - val_mean_squared_error: 12290.0957
# Epoch 206/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33731.6758 - mean_squared_error: 14162.1543 - val_loss: 29727.9492 - val_mean_squared_error: 12407.8701
# Epoch 207/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33659.9922 - mean_squared_error: 14130.0957 - val_loss: 29839.9961 - val_mean_squared_error: 12541.7881
# Epoch 208/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34319.4883 - mean_squared_error: 14467.7295 - val_loss: 33072.6914 - val_mean_squared_error: 14137.7520
# Epoch 209/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 38967.0000 - mean_squared_error: 16743.6816 - val_loss: 28842.7461 - val_mean_squared_error: 12041.9043
# Epoch 210/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36164.5000 - mean_squared_error: 15337.1367 - val_loss: 30367.8320 - val_mean_squared_error: 12790.9355
# Epoch 211/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 38370.9258 - mean_squared_error: 16422.8340 - val_loss: 28779.1836 - val_mean_squared_error: 12009.3398
# Epoch 212/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33796.0469 - mean_squared_error: 14201.3691 - val_loss: 28206.7461 - val_mean_squared_error: 11754.9629
# Epoch 213/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32644.8086 - mean_squared_error: 13689.4785 - val_loss: 28073.4453 - val_mean_squared_error: 11701.2012
# Epoch 214/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32314.9785 - mean_squared_error: 13543.5762 - val_loss: 28413.1699 - val_mean_squared_error: 11841.4912
# Epoch 215/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32230.8750 - mean_squared_error: 13505.7656 - val_loss: 28277.0273 - val_mean_squared_error: 11776.4863
# Epoch 216/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32316.4824 - mean_squared_error: 13550.6152 - val_loss: 27932.7109 - val_mean_squared_error: 11634.9385
# Epoch 217/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32126.2676 - mean_squared_error: 13460.3398 - val_loss: 28216.4922 - val_mean_squared_error: 11768.9062
# Epoch 218/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32361.0801 - mean_squared_error: 13568.3213 - val_loss: 28673.2422 - val_mean_squared_error: 11977.1797
# Epoch 219/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32702.8574 - mean_squared_error: 13732.1631 - val_loss: 28760.6699 - val_mean_squared_error: 12025.3027
# Epoch 220/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32749.8848 - mean_squared_error: 13759.2705 - val_loss: 29185.0000 - val_mean_squared_error: 12179.1982
# Epoch 221/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32789.2500 - mean_squared_error: 13777.5488 - val_loss: 28524.5586 - val_mean_squared_error: 11890.3477
# Epoch 222/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32500.1992 - mean_squared_error: 13639.4697 - val_loss: 30268.2969 - val_mean_squared_error: 12756.0645
# Epoch 223/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35147.1289 - mean_squared_error: 14961.0908 - val_loss: 31860.9688 - val_mean_squared_error: 13479.8359
# Epoch 224/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 48725.8086 - mean_squared_error: 21500.0684 - val_loss: 31289.5312 - val_mean_squared_error: 13187.2529
# Epoch 225/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37703.6484 - mean_squared_error: 16016.1660 - val_loss: 29395.9883 - val_mean_squared_error: 12314.4355
# Epoch 226/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34368.4922 - mean_squared_error: 14467.2891 - val_loss: 28581.2598 - val_mean_squared_error: 11933.7148
# Epoch 227/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32953.9648 - mean_squared_error: 13836.6914 - val_loss: 28510.1758 - val_mean_squared_error: 11898.5723
# Epoch 228/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32513.0957 - mean_squared_error: 13639.6426 - val_loss: 28729.1582 - val_mean_squared_error: 11995.0684
# Epoch 229/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32417.8145 - mean_squared_error: 13601.4824 - val_loss: 28427.9336 - val_mean_squared_error: 11861.4258
# Epoch 230/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32524.8867 - mean_squared_error: 13651.1025 - val_loss: 28637.6777 - val_mean_squared_error: 11966.6973
# Epoch 231/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32751.6367 - mean_squared_error: 13768.7109 - val_loss: 28463.3594 - val_mean_squared_error: 11873.5010
# Epoch 232/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32499.8438 - mean_squared_error: 13643.1133 - val_loss: 28709.6719 - val_mean_squared_error: 11964.0508
# Epoch 233/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32269.3379 - mean_squared_error: 13532.5801 - val_loss: 28608.3711 - val_mean_squared_error: 11922.8555
# Epoch 234/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32043.1934 - mean_squared_error: 13440.8232 - val_loss: 28680.0410 - val_mean_squared_error: 11970.5645
# Epoch 235/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31925.3984 - mean_squared_error: 13395.3096 - val_loss: 28499.2578 - val_mean_squared_error: 11879.6523
# Epoch 236/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31599.1914 - mean_squared_error: 13246.9316 - val_loss: 28507.9102 - val_mean_squared_error: 11875.5469
# Epoch 237/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31394.4297 - mean_squared_error: 13154.3408 - val_loss: 28371.9355 - val_mean_squared_error: 11828.1406
# Epoch 238/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31828.2305 - mean_squared_error: 13379.1621 - val_loss: 28469.9336 - val_mean_squared_error: 11892.2598
# Epoch 239/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34296.0195 - mean_squared_error: 14574.8652 - val_loss: 28630.4453 - val_mean_squared_error: 11963.9746
# Epoch 240/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33460.7070 - mean_squared_error: 14167.8076 - val_loss: 32351.6328 - val_mean_squared_error: 13800.5195
# Epoch 241/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35645.4766 - mean_squared_error: 15248.9971 - val_loss: 28520.6309 - val_mean_squared_error: 11906.3428
# Epoch 242/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31916.9512 - mean_squared_error: 13397.5166 - val_loss: 28958.7539 - val_mean_squared_error: 12076.5664
# Epoch 243/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32292.7500 - mean_squared_error: 13591.8379 - val_loss: 29289.3027 - val_mean_squared_error: 12241.6348
# Epoch 244/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32245.0742 - mean_squared_error: 13545.9102 - val_loss: 29950.0176 - val_mean_squared_error: 12523.2031
# Epoch 245/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32751.1289 - mean_squared_error: 13774.9521 - val_loss: 29144.1133 - val_mean_squared_error: 12162.1699
# Epoch 246/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32205.1309 - mean_squared_error: 13518.7666 - val_loss: 29775.3242 - val_mean_squared_error: 12424.5645
# Epoch 247/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32236.5430 - mean_squared_error: 13527.0645 - val_loss: 29299.8633 - val_mean_squared_error: 12212.5400
# Epoch 248/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32366.0684 - mean_squared_error: 13592.2217 - val_loss: 29096.6660 - val_mean_squared_error: 12151.5664
# Epoch 249/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33308.7188 - mean_squared_error: 14043.0820 - val_loss: 29463.8691 - val_mean_squared_error: 12316.9307
# Epoch 250/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33573.0469 - mean_squared_error: 14205.1152 - val_loss: 28183.1211 - val_mean_squared_error: 11758.1064
# Epoch 251/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32417.1875 - mean_squared_error: 13680.1367 - val_loss: 32742.0703 - val_mean_squared_error: 14030.6377
# Epoch 252/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34855.7930 - mean_squared_error: 14893.8926 - val_loss: 29007.4492 - val_mean_squared_error: 12161.3867
# Epoch 253/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33618.0430 - mean_squared_error: 14279.1016 - val_loss: 29418.6484 - val_mean_squared_error: 12327.1191
# Epoch 254/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34136.2344 - mean_squared_error: 14523.1631 - val_loss: 29072.4219 - val_mean_squared_error: 12180.2070
# Epoch 255/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31880.0996 - mean_squared_error: 13416.7998 - val_loss: 28397.4492 - val_mean_squared_error: 11853.5332
# Epoch 256/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31293.1133 - mean_squared_error: 13135.3477 - val_loss: 29031.9727 - val_mean_squared_error: 12141.8574
# Epoch 257/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31457.6250 - mean_squared_error: 13210.0605 - val_loss: 29055.2383 - val_mean_squared_error: 12119.5664
# Epoch 258/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31465.1895 - mean_squared_error: 13200.3301 - val_loss: 28477.4570 - val_mean_squared_error: 11894.4707
# Epoch 259/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31396.8926 - mean_squared_error: 13183.9980 - val_loss: 28689.7852 - val_mean_squared_error: 12027.8525
# Epoch 260/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31882.2070 - mean_squared_error: 13435.1973 - val_loss: 27995.0410 - val_mean_squared_error: 11683.8203
# Epoch 261/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31171.0449 - mean_squared_error: 13083.2646 - val_loss: 27789.0625 - val_mean_squared_error: 11582.3193
# Epoch 262/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31311.3242 - mean_squared_error: 13160.3477 - val_loss: 27693.6719 - val_mean_squared_error: 11544.3809
# Epoch 263/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32816.1875 - mean_squared_error: 13892.2217 - val_loss: 28211.1406 - val_mean_squared_error: 11794.4414
# Epoch 264/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32440.4648 - mean_squared_error: 13709.1611 - val_loss: 30527.3945 - val_mean_squared_error: 12939.8574
# Epoch 265/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32960.9453 - mean_squared_error: 13970.5244 - val_loss: 29711.9922 - val_mean_squared_error: 12529.9717
# Epoch 266/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33964.8594 - mean_squared_error: 14466.3613 - val_loss: 28654.9453 - val_mean_squared_error: 11959.3398
# Epoch 267/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33002.4805 - mean_squared_error: 13986.3740 - val_loss: 28692.0684 - val_mean_squared_error: 11992.3418
# Epoch 268/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31400.5840 - mean_squared_error: 13188.3877 - val_loss: 28360.8281 - val_mean_squared_error: 11840.9980
# Epoch 269/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31075.4238 - mean_squared_error: 13041.6250 - val_loss: 28577.2031 - val_mean_squared_error: 11914.9629
# Epoch 270/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31007.9863 - mean_squared_error: 13002.8838 - val_loss: 28402.6758 - val_mean_squared_error: 11830.1826
# Epoch 271/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30916.8691 - mean_squared_error: 12959.3037 - val_loss: 28282.5977 - val_mean_squared_error: 11778.5020
# Epoch 272/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30716.9629 - mean_squared_error: 12880.5840 - val_loss: 28847.4023 - val_mean_squared_error: 12024.9746
# Epoch 273/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30944.2734 - mean_squared_error: 12980.5957 - val_loss: 29255.1641 - val_mean_squared_error: 12239.6992
# Epoch 274/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31301.5762 - mean_squared_error: 13157.8496 - val_loss: 29638.2344 - val_mean_squared_error: 12429.0479
# Epoch 275/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31986.0098 - mean_squared_error: 13494.1465 - val_loss: 29146.1758 - val_mean_squared_error: 12201.6973
# Epoch 276/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31819.8965 - mean_squared_error: 13426.1289 - val_loss: 28812.6934 - val_mean_squared_error: 12042.7412
# Epoch 277/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31658.4434 - mean_squared_error: 13344.7109 - val_loss: 31670.2305 - val_mean_squared_error: 13466.1982
# Epoch 278/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 38452.1367 - mean_squared_error: 16643.0605 - val_loss: 29340.2031 - val_mean_squared_error: 12289.9434
# Epoch 279/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 36134.6875 - mean_squared_error: 15498.0898 - val_loss: 30152.2305 - val_mean_squared_error: 12688.1973
# Epoch 280/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34534.8203 - mean_squared_error: 14739.1602 - val_loss: 29553.5625 - val_mean_squared_error: 12358.5586
# Epoch 281/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35750.6797 - mean_squared_error: 15295.3613 - val_loss: 29812.5762 - val_mean_squared_error: 12456.0869
# Epoch 282/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32184.8301 - mean_squared_error: 13584.8428 - val_loss: 29298.1172 - val_mean_squared_error: 12296.5078
# Epoch 283/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34089.0664 - mean_squared_error: 14547.4395 - val_loss: 29271.0664 - val_mean_squared_error: 12262.5352
# Epoch 284/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32955.1016 - mean_squared_error: 13989.8203 - val_loss: 30698.8906 - val_mean_squared_error: 13004.8066
# Epoch 285/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 35395.0938 - mean_squared_error: 15194.8770 - val_loss: 34740.3320 - val_mean_squared_error: 14971.3242
# Epoch 286/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42303.8008 - mean_squared_error: 18541.0098 - val_loss: 39026.0156 - val_mean_squared_error: 17091.8906
# Epoch 287/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 47736.8945 - mean_squared_error: 21066.8633 - val_loss: 32719.7031 - val_mean_squared_error: 13946.2061
# Epoch 288/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 38026.1680 - mean_squared_error: 16354.7080 - val_loss: 29239.2148 - val_mean_squared_error: 12251.3906
# Epoch 289/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33116.5508 - mean_squared_error: 13998.2705 - val_loss: 28179.7930 - val_mean_squared_error: 11745.2637
# Epoch 290/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30829.8926 - mean_squared_error: 12938.2480 - val_loss: 27719.6797 - val_mean_squared_error: 11546.5879
# Epoch 291/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30401.8457 - mean_squared_error: 12752.3574 - val_loss: 27865.4766 - val_mean_squared_error: 11609.8203
# Epoch 292/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30333.9961 - mean_squared_error: 12725.4688 - val_loss: 27979.7031 - val_mean_squared_error: 11662.6885
# Epoch 293/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30538.7148 - mean_squared_error: 12822.3057 - val_loss: 28173.8281 - val_mean_squared_error: 11750.8203
# Epoch 294/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30572.9531 - mean_squared_error: 12846.6982 - val_loss: 28161.2598 - val_mean_squared_error: 11748.2324
# Epoch 295/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30487.0820 - mean_squared_error: 12812.4639 - val_loss: 27856.2695 - val_mean_squared_error: 11618.8477
# Epoch 296/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30426.8574 - mean_squared_error: 12784.6182 - val_loss: 28195.0586 - val_mean_squared_error: 11763.0430
# Epoch 297/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30584.5703 - mean_squared_error: 12849.6992 - val_loss: 28750.5039 - val_mean_squared_error: 11992.9199
# Epoch 298/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30660.3203 - mean_squared_error: 12870.2314 - val_loss: 28196.1484 - val_mean_squared_error: 11752.1279
# Epoch 299/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30468.0078 - mean_squared_error: 12786.4521 - val_loss: 28335.6055 - val_mean_squared_error: 11819.6777
# Epoch 300/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30439.5586 - mean_squared_error: 12777.6016 - val_loss: 28267.5820 - val_mean_squared_error: 11787.5039
# Epoch 301/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30393.7148 - mean_squared_error: 12765.7812 - val_loss: 28098.4375 - val_mean_squared_error: 11732.4258
# Epoch 302/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30170.4746 - mean_squared_error: 12677.9385 - val_loss: 28022.0176 - val_mean_squared_error: 11706.9824
# Epoch 303/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30461.0664 - mean_squared_error: 12805.9453 - val_loss: 28034.6523 - val_mean_squared_error: 11713.7266
# Epoch 304/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31421.4688 - mean_squared_error: 13235.7354 - val_loss: 29560.2656 - val_mean_squared_error: 12394.2939
# Epoch 305/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32508.9883 - mean_squared_error: 13744.0010 - val_loss: 29901.5156 - val_mean_squared_error: 12581.3115
# Epoch 306/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32389.3184 - mean_squared_error: 13722.5508 - val_loss: 29543.9375 - val_mean_squared_error: 12409.1348
# Epoch 307/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 32309.6328 - mean_squared_error: 13711.5537 - val_loss: 30406.6211 - val_mean_squared_error: 12852.7871
# Epoch 308/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33017.4141 - mean_squared_error: 14084.1426 - val_loss: 30560.6055 - val_mean_squared_error: 12947.9268
# Epoch 309/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 33152.5625 - mean_squared_error: 14136.0000 - val_loss: 30300.5898 - val_mean_squared_error: 12786.0566
# Epoch 310/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 31986.6484 - mean_squared_error: 13555.5371 - val_loss: 29087.1680 - val_mean_squared_error: 12172.7129
# Epoch 311/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 30585.6055 - mean_squared_error: 12872.7949 - val_loss: 28155.2109 - val_mean_squared_error: 11731.1885
# Epoch 312/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 29629.4297 - mean_squared_error: 12419.2773 - val_loss: 27694.4297 - val_mean_squared_error: 11532.4893

# %% [markdown]
# ##  Save trained model

# %%
model.save('PaviaC_2x_saved_model.keras')

# %% [markdown]
# ## Report the six types of results in terms of PSNR, SSIM, SAM, Correlation Coefficient, ERGAS, and RMSE.

# %%
def psnr(y_true, y_pred, max_pixel=None):
    """
    Compute PSNR for each spectral band separately and return the average.
    
    Args:
        y_true: Ground truth image, shape (H, W, B)
        y_pred: Super-resolved image, shape (H, W, B)
        max_pixel: Maximum pixel value (None = use actual max from y_true)
    
    Returns:
        Average PSNR across all bands
    """
    if max_pixel is None:
        max_pixel = np.max(y_true)  # Auto-detect max value if not provided

    B = y_true.shape[-1]  # Number of spectral bands
    psnr_values = []
    
    for i in range(B):  # Loop over bands
        mse = np.mean((y_true[..., i] - y_pred[..., i]) ** 2)
        if mse == 0:
            psnr_values.append(float('inf'))  # Perfect reconstruction
        else:
            psnr = 20 * np.log10(max_pixel / np.sqrt(mse))
            psnr_values.append(psnr)
    
    return np.mean(psnr_values)  # Average across bands

# Function to calculate SSIM with channel_axis
def ssim_value(y_true, y_pred):
    if y_true.shape != y_pred.shape:
        raise ValueError(f"Shape mismatch: y_true shape {y_true.shape} vs y_pred shape {y_pred.shape}")
    
    data_range = y_true.max() - y_true.min()  # Calculate data range from y_true
    ssim_val = ssim(y_true, y_pred, data_range=data_range, channel_axis=-1)
    return ssim_val

# Function to calculate Correlation Coefficient
def correlation_coefficient(y_true, y_pred):
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()
    corr_matrix = np.corrcoef(y_true_flat, y_pred_flat)
    corr_value = corr_matrix[0, 1]
    return corr_value

# Function to calculate Spectral Angle Mapper (SAM) in degrees
def sam(y_true, y_pred):
    y_true_reshaped = y_true.reshape(-1, y_true.shape[-1])
    y_pred_reshaped = y_pred.reshape(-1, y_pred.shape[-1])
    
    non_zero_mask = (np.linalg.norm(y_true_reshaped, axis=1) > 1e-10) & (np.linalg.norm(y_pred_reshaped, axis=1) > 1e-10)
    dot_product = np.sum(y_true_reshaped[non_zero_mask] * y_pred_reshaped[non_zero_mask], axis=1)
    norm_true = np.linalg.norm(y_true_reshaped[non_zero_mask], axis=1)
    norm_pred = np.linalg.norm(y_pred_reshaped[non_zero_mask], axis=1)
    
    with np.errstate(divide='ignore', invalid='ignore'):
        angles = np.arccos(np.clip(dot_product / (norm_true * norm_pred), -1.0, 1.0))
    
    if angles.size > 0:
        sam_value_degrees = np.mean(angles) * (180 / np.pi)
    else:
        sam_value_degrees = 0
    
    return sam_value_degrees

# Function to normalize the images
def normalize(image):
    min_val = np.min(image)
    max_val = np.max(image)
    return (image - min_val) / (max_val - min_val)  # Normalize to [0, 1]

# Function to calculate Root Mean Squared Error (RMSE) for hyperspectral images (normalized)
def rmse_bandwise(y_true, y_pred):
    if y_true.shape != y_pred.shape:
        raise ValueError("Shape mismatch between true and predicted images.")
    
    bands = y_true.shape[-1]
    rmse_per_band = []

    for b in range(bands):
        band_true = y_true[:, :, b]
        band_pred = y_pred[:, :, b]
        
        mse_band = np.mean((band_true - band_pred) ** 2)
        rmse_band_value = np.sqrt(mse_band)
        rmse_per_band.append(rmse_band_value)

    # Normalize RMSE by the maximum value in y_true across all bands
    max_value = np.max(y_true)
    normalized_rmse = np.mean(rmse_per_band) / max_value
    return normalized_rmse

# Function to calculate ERGAS
def ergas(y_true, y_pred, scale):
    bands = y_true.shape[-1]
    ergas_value = 0
    
    for b in range(bands):
        band_true = y_true[:, :, b]
        band_pred = y_pred[:, :, b]
        mean_band_true = np.mean(band_true)
        
        # Calculate RMSE for the band without using a separate function
        mse_band = np.mean((band_true - band_pred) ** 2)  # Mean Squared Error for the band
        rmse_band = np.sqrt(mse_band)  # Root Mean Squared Error for the band
        
        ergas_value += (rmse_band / mean_band_true) ** 2
    
    ergas_value = 100 * (1 / scale) * np.sqrt(ergas_value / bands)
    return ergas_value

# Assuming hybrid_sr_model is trained, and X_test_lr, X_test_hr are defined
predicted_hr_images =  model.predict(X_test_lr)

downscale_factor = 2 # ERGAS downscale factor

# Validate shapes match for test and predictions
if predicted_hr_images.shape != X_test_hr.shape:
    raise ValueError(f"Shape mismatch: predicted_hr_images shape {predicted_hr_images.shape} vs X_test_hr shape {X_test_hr.shape}")

# Calculate metrics per test sample
psnr_values, ssim_values, cc_values, sam_values, ergas_values, rmse_values = [], [], [], [], [], []

for i in range(len(X_test_hr)):
    psnr_values.append(psnr(X_test_hr[i], predicted_hr_images[i]))
    ssim_values.append(ssim_value(X_test_hr[i], predicted_hr_images[i]))
    cc_values.append(correlation_coefficient(X_test_hr[i], predicted_hr_images[i]))
    sam_values.append(sam(X_test_hr[i], predicted_hr_images[i]))
    rmse_values.append(rmse_bandwise(X_test_hr[i], predicted_hr_images[i]))

# Average metrics
average_psnr = np.mean(psnr_values)
average_ssim = np.mean(ssim_values)
average_cc = np.mean(cc_values)
average_sam = np.mean(sam_values)
average_rmse = np.mean(rmse_values)

# Print the evaluation metrics
print("Average PSNR on the test set:", average_psnr)
print("Average SSIM on the test set:", average_ssim)
print("Average SAM on the test set (in degrees):", average_sam)
print("Average Correlation Coefficient on the test set:", average_cc)
print("Average RMSE:", average_rmse)  # Indicate RMSE is normalized
# Out:
# 2025-07-30 19:55:08.586720: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Average PSNR on the test set: 36.8409318725268
# Average SSIM on the test set: 0.9595148
# Average SAM on the test set (in degrees): 3.5314936016246747
# Average Correlation Coefficient on the test set: 0.9836549219513607
# Average RMSE: 0.014535847
